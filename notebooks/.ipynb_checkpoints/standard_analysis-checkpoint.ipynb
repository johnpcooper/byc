# %%
from importlib import reload
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from byc import standard_analysis as sa
from byc import database, plotting, files, utilities

plt.style.use('default')
matplotlib.rcParams['font.sans-serif'] = 'Arial'

# %% [markdown]
# Read in the data by selecting the master_index .csv for the experiment being analyzed. For this tutorial located at `...\byc_data\example_byc_expts\20200221_byc_analysis\20200221_byc_master_index.csv`

# %%
traces, filenames = sa.set_processed_traces(3, 10)
# Out:
# value is  0
# cells_dfs is now 1 elements long
# Checking senescence data for cell 0
# sen_value is False
# first_frame is 1
# last_frame is 1
# sen_distance_from_start is -1
# Processing trace dataframe for cell 0 of 0

# %% [markdown]
# Have a look at the trace database to get a sense of what entries should look like

# %%
from byc import database
tracedb = database.byc_database
tracedb.trace_database_df.head()
# Out:
#                       expt_name  \
# 0  20191106_byc_by4741_young_NS
# 1  20191106_byc_by4741_young_NS
# 2  20191106_byc_by4741_young_NS
# 3  20191106_byc_by4741_young_NS
# 4  20191106_byc_by4741_young_NS
#
#                                           trace_path chase_index bud_roi_path  \
# 0  C:\Users\John Cooper\Projects\byc\data\2019110...           5          NaN
# 1  C:\Users\John Cooper\Projects\byc\data\2019110...           5          NaN
# 2  C:\Users\John Cooper\Projects\byc\data\2019110...           5          NaN
# 3  C:\Users\John Cooper\Projects\byc\data\2019110...           5          NaN
# 4  C:\Users\John Cooper\Projects\byc\data\2019110...           5          NaN
#
#                                        trace_relpath      date
# 0  20191106_byc\analysis\20191106_byc_by4741_youn...  20191106
# 1  20191106_byc\analysis\20191106_byc_by4741_youn...  20191106
# 2  20191106_byc\analysis\20191106_byc_by4741_youn...  20191106
# 3  20191106_byc\analysis\20191106_byc_by4741_youn...  20191106
# 4  20191106_byc\analysis\20191106_byc_by4741_youn...  20191106

# %% [markdown]
# Create an experiment name to use when adding this experiment to the byc trace database

# %%
expt_name = "20200221_byc_JC069_rpn4d"

# %% [markdown]
# Add this experiment to trace database

# %%
tracedb.add_expt_to_trace_database(filenames, expt_name, chase_index=np.NaN, date='20200221')

# %% [markdown]
# Have a look at what you just added

# %%
tracedb.trace_database_df.set_index('expt_name').loc[expt_name, :]
# Out:
# trace_path      C:\Users\John Cooper\Box Sync\Finkelstein-Mato...
# chase_index                                                   NaN
# bud_roi_path                                                  NaN
# Name: 20200221_byc_JC069_rpn4d, dtype: object

# %% [markdown]
# Read experiment trace dataframes in using database

# %%
cell_dfs = tracedb.get_cell_trace_dfs(expt_name)

# %%
fig = plt.figure(figsize=(5, 2))
fig.set_dpi(300)

df = cell_dfs[0]
ax = plt.axes()

yfp_norm = df.yfp_mean/df.yfp_mean.min()
dsred_norm = df.dsred_mean/df.dsred_mean.min()

ax.set_ylabel("Intensity/Intensity min.")
ax.set_xlabel("Time (hrs.)")

ax.set_xlim(0, 2)
#ax.set_ylim(1, 1.8)

ax.plot(df.hours, dsred_norm, color='red')
ax.plot(df.hours, yfp_norm, color='orange')

ax2 = ax.twinx()
ax2.set_ylabel("YFP/DsRed")

ax2.plot(df.hours, yfp_norm/dsred_norm, color='purple')

custom_lines = [Line2D([0], [0], color='red', lw=2),
                Line2D([0], [0], color='orange', lw=2),
                Line2D([0], [0], color='purple', lw=2)]

ax.legend(custom_lines, ['DsRed',
                         'YFP',
                         'Ratio'], fontsize=8)

plt.show()

# %% [markdown]
# ### 20201127_byc

# %%
import os
from importlib import reload
import re

import numpy as np
import pandas as pd
from skimage.draw import line
from skimage import io
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('default')
matplotlib.rcParams['font.sans-serif'] = 'Arial'
import seaborn as sns

from read_roi import read_roi_zip

from byc import files, utilities, constants
from byc.imagejpc import addcellroi
import byc.standard_analysis as sa

for mod in [files, addcellroi, constants, utilities, sa]:
    reload(mod)

# %% [markdown]
# ### Creating a master index using crop_roi_dfs made by imagejpc/save_cell_roi_set.py

# %%
# Create a master index data frame for the purpose
# of running byc/bin/run_segmentation to crop and
# Otsu threshold based on crop ROIs
write = True
compartment_dir = r"C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg"
exptdir = os.path.dirname(compartment_dir)
pattern = constants.patterns.crop_roi_df_file
paths = utilities.get_filepaths_with_pattern(pattern,
                                             rootdir=exptdir)
bud_paths = utilities.get_filepaths_with_pattern(constants.patterns.bud_roi_df_file,
                                                 rootdir=exptdir)

dfs = [pd.read_csv(p) for p in paths]
mdf = pd.concat(dfs, ignore_index=True)
exptdir = os.path.dirname(mdf.compartment_dir.unique()[0])
# Manual fix. crop_roi_dfs were created when
# save cell roi set still defaulted to 'dsred'
mdf.loc[:, 'channels_collected'] = 'bf yfp rfp'
# Merge bud data into master index
budfs = [pd.read_csv(p) for p in bud_paths]
bud_mdf = pd.concat(budfs)
bud_mdf = bud_mdf.set_index(['xy', 'cell_index'])
mdf = mdf.set_index(['xy', 'cell_index'])
starting_cols = mdf.columns
for ind in bud_mdf.index:
    if ind in mdf.index:
        for col in bud_mdf.columns:
            if col not in starting_cols:
                mdf.loc[ind, col] = bud_mdf.loc[ind, col]
                
mdf.reset_index(inplace=True)
# mdf_path = utilities.get_all_master_index_paths(exptdir)[0]
mdf_path = os.path.join(exptdir, '20201127_master_index_analysis.csv')
if write:
    # Save the updated master_index
    mdf.to_csv(mdf_path, index=False)

# %%
compartment_dir = r"C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg"
exptdir = os.path.dirname(compartment_dir)
mdf_path = os.path.join(exptdir, '20201127_master_index_analysis.csv')
mdf = pd.read_csv(mdf_path)

# %%
bycds = sa.bycDataSet(mdf=mdf)
alldfs = bycds.cell_trace_dfs
# Out:
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell000_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell000_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell000_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell001_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell001_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell001_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell002_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell002_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell003_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell003_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell003_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell004_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell004_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell004_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell005_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell005_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell005_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell006_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell006_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell006_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell007_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell007_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell007_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell008_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell008_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell008_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell008_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell009_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell009_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_xy00_cell009_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell009_crop_rois.zip
# No data found for cell with pattern: (20201127_byc_xy00_cell010)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell011)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell012)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell013)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell014)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell015)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell016)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# No data found for cell with pattern: (20201127_byc_xy00_cell017)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg
# Found data for cell 18 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell000_crop_rois.zip
# Found data for cell 18 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell000_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell000_crop_rois.zip
# Found data for cell 19 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell001_crop_rois.zip
# Found data for cell 19 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell001_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell001_crop_rois.zip
# Found data for cell 20 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell002_crop_rois.zip
# Found data for cell 20 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell002_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell002_crop_rois.zip
# Found data for cell 21 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell003_crop_rois.zip
# Found data for cell 21 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell003_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell003_crop_rois.zip
# Found data for cell 22 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell004_crop_rois.zip
# Found data for cell 22 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell004_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell004_crop_rois.zip
# Found data for cell 23 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell005_crop_rois.zip
# Found data for cell 23 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell005_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell005_crop_rois.zip
# Found data for cell 24 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell006_crop_rois.zip
# Found data for cell 24 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell006_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell006_crop_rois.zip
# Found data for cell 25 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell007_crop_rois.zip
# Found data for cell 25 at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_xy05_cell007_yfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI\20201127_byc_cell007_crop_rois.zip
# No data found for cell with pattern: (20201127_byc_xy05_cell008)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI
# No data found for cell with pattern: (20201127_byc_xy05_cell009)_(.+)_(stack.csv)
# Checked compartment dir: C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC197_NLS-mScarletI

# %%
df = pd.concat(alldfs, ignore_index=True)
df = df.sort_values(by='total_hours')

# %% [markdown]
# ### Plots with YFP and RFP

# %%
colors = sns.color_palette("hls", 10)
green = colors[3]
red = colors[0]

# %%
def get_bud_hours(celldf, reference='death'):
    """
    Return a numpy array containing timepoints
    of bud appearances
    """
    try:
        collection_interval = celldf.collection_interval.unique()[0]
    except:
        collection_interval = 10
        print(f'Warning! Defaulting to collection interval of {collection_interval} minutes')

    # Create empty columns
    bud_rois_inds = np.full(len(celldf), np.nan)
    bud_abs_hours = np.full(len(celldf), np.nan)
    bud_hours =  np.full(len(celldf), np.nan)
    bud_hours_to_death = np.full(len(celldf), np.nan)

    if True in celldf.bud_roi_set_path.values:
        print(f'No path found in celldf with xy {celldf.xy.unique()[0]} and cell_index{celldf.cell_index.unique()[0]}')
        return None
    else:
        bud_rois_path = celldf.bud_roi_set_path.iloc[0]
        print(bud_rois_path)
        bud_rois_inds = files.read_roi_position_indices(bud_rois_path)
        bud_abs_hours = (bud_rois_inds*collection_interval)/60
        bud_hours =  bud_abs_hours - celldf.abs_hours.min()
        bud_hours_to_death = celldf.hours.max() - bud_hours

    vals = [bud_rois_inds,
            bud_abs_hours,
            bud_hours,
            bud_hours_to_death]

    keys = ['bud_rois_inds',
            'bud_abs_hours',
            'bud_hours',
            'bud_hours_to_death']
    
    if reference == 'death':
        return bud_hours_to_death
    elif reference == 'experiment_start':
        return bud_abs_hours
    elif reference == 'cell_obs_start':
        return bud_hours
    else:
        print(f"Bad reference passed: {reference}")
        print("Returning bud roi frame indices")
        return bud_roi_inds

# %% [markdown]
# Single axis

# %%
ax.axvline?
# Out:
# Object `ax.axvline` not found.

# %%
plasmid_name = 'pJC189'
subdf = df.loc[df.plasmid == plasmid_name]
# subdf = subdf[subdf.end_event_type=='death']
y_var = 'Mean_rfp'
y_var2 = 'Mean_yfp'
dfs = [subdf.loc[subdf.cell_index==i, :].sort_values(by='hours') for i in subdf.cell_index.unique()]
mins = np.array([celldf.loc[:, y_var].min() for celldf in dfs])
mins2 = np.array([celldf.loc[:, y_var2].min() for celldf in dfs])
bg = np.median(mins)
bg = 800
bg2 = 500
offset_step = 5000
y_ul = offset_step*len(dfs)
x_ul = 80
fig = plt.figure(figsize=(3, 0.4*len(dfs)))
fig.set_dpi(250)
colors = sns.color_palette("hls", len(dfs))
ax = plt.axes()
ax.set_xlim(x_ul, -5)
ax.set_ylim(0, y_ul)
ax.set_yticks(np.arange(0, y_ul+1, offset_step))
ax.set_ylabel('Mean Intensity in Cell (a.u.)')
ax.set_xlabel('Hours to death')

y_var = 'Mean_rfp'
for i, celldf in enumerate(dfs):
    print('y_var range: ', celldf[y_var].max() - celldf[y_var].min())
    print('y_var2 range: ', celldf[y_var2].max() - celldf[y_var2].min())
    offset = offset_step*i
    cell_index = celldf.cell_index.iloc[0]
    ax.text(x_ul-2, offset + 0.5*offset_step, f'Cell {cell_index}',
            fontsize=10, color='gray', alpha=0.8)
    ax.axhline(offset, linewidth=0.5, color='black')
      
    y = celldf[y_var] + offset - bg
    y2 = celldf[y_var2] + offset - bg2
    if True in celldf.hours_to_death.isna().values:
        x = celldf.hours.max() - celldf.hours
        ax.scatter(x[x.index[-1]], y[y.index[-1]],
                   facecolor='white', edgecolor='black', linewidth=1, s=15)
        print(f"No hours to death for cell {cell_index}. \nFinal frame is end of expt")
    else:
        x = celldf.hours_to_death
    ax.plot(x, y,
            color=red, linewidth=1.5)
    ax.plot(x, y2,
            color=green, linewidth=1.5)
    
    # Annotate bud appearance hours
    bud_hours_to_death = get_bud_hours(celldf=celldf, reference='death')
    for hour in bud_hours_to_death:
        x = hour
        ymin = offset_step*(i)
        ymin = ymin/(len(dfs)*offset_step)
        ymax = offset_step*(i+1)
        ymax = ymax/(len(dfs)*offset_step)
        ax.axvline(x=x, ymin=ymin, ymax=ymax,
                   color='black', alpha=0.3, linewidth=0.5)

      
names = ['top', 'right']

for spine in [ax.spines[n] for n in names]:
    spine.set_visible(False)
    
fig.savefig(os.path.join(exptdir, f'{plasmid_name}.svg'))
# Out:
# y_var range:  2069.4169999999995
# y_var2 range:  2517.3740000000003
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell006_bud_rois.zip
# y_var range:  2179.702
# y_var2 range:  2037.872
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell004_bud_rois.zip
# y_var range:  1160.897
# y_var2 range:  2389.883
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell009_bud_rois.zip
# y_var range:  2685.3730000000005
# y_var2 range:  2908.9069999999997
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell007_bud_rois.zip
# y_var range:  2334.029
# y_var2 range:  3645.104
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell000_bud_rois.zip
# y_var range:  2387.595
# y_var2 range:  2192.7270000000003
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell005_bud_rois.zip
# y_var range:  2195.561
# y_var2 range:  2115.885
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell008_bud_rois.zip
# y_var range:  2359.937
# y_var2 range:  2368.2490000000003
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell003_bud_rois.zip
# y_var range:  1953.734
# y_var2 range:  2355.097
# No hours to death for cell 2.
# Final frame is end of expt
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell002_bud_rois.zip
# y_var range:  1627.484
# y_var2 range:  2009.7740000000001
# No hours to death for cell 1.
# Final frame is end of expt
# Warning! Defaulting to collection interval of 10 minutes
# C:\Users\John Cooper\Projects\byc\data\20201127_byc\pJC189_mScarletI-1013deg\20201127_byc_cell001_bud_rois.zip

# %%
import seaborn as sns
table = df.pivot_table(index=['plasmid', 'Slice_rfp'], aggfunc='mean').reset_index()
ax = sns.scatterplot(data=table, x='hours_to_death', y='RawIntDen_rfp', hue='plasmid')
ax.set_xlim(80, -10)
# Out:
# (80.0, -10.0)

# %%
for celldf in dfs:
    print(celldf.loc[:, y_var].min())
# Out:
# 802.0189999999999
# 1022.688
# 916.819
# 921.283
# 1326.838
# 1093.868
# 1152.421
# 1061.052
# 1114.752
# 1080.03
# 866.8
# 1124.985
# 1072.111
# 964.53
# 951.44
# 1268.097
# 1104.563
# 861.878
