# %% [markdown]
# # Cell segmentation in byc
# The workflow for segmentation is a combination of manual annotation in imagej assisted by plugins and macros in `imagejpc` and data processing in python with functions from `byc.segmentation`

# %% [markdown]
# ## ImageJ scripts (imagejpc) installation
# ### Clone `imagejpc` repo

# %% [markdown]
# ```sh
# git clone https://github.com/johnpcooper/imagejpc.git
# tree imagejpc
# imagejpc
# ├── Keyboard_Shortcuts.xls
# ├── README.md
# ├── macros
# │   ├── create_and_measure_rois.ijm
# │   ├── scale_rois.ijm
# │   └── threshold_brightfield.ijm
# └── utilities
#     ├── get_percentile.py
#     ├── measure_and_clear_rois.py
#     ├── measure_background.py
#     ├── measure_rois.py
#     ├── measure_steady_state.py
#     ├── record_cell.py
#     ├── save_cell_measurement_rois.py
#     ├── save_cell_roi_set.py
#     ├── save_rois.py
#     ├── save_tifs.py
#     ├── split_and_save_stack.py
#     └── time_stamper_jpc.py
# ```

# %% [markdown]
# ### Get plugins and macros installed in `imagejpc`
# 1. Install [Fiji](https://imagej.net/Fiji/Downloads) if not already installed.
#
#
# 2. Open imagej, click Plugins > Macros > Install > Select macros (one at a time, ugh) from path/to/imagejpc/macros
#
#
# 3. Click Plugins > Install PlugIn > Select .py files (one at a time) from path/to/imagejpc/utilities
#
#
# 4. Click Plugins > Shortcuts > Add Shortcut... to make shortcut for shortcuts in `Keyboard_Shortcuts.xls`
#
#
# 4. Restart imagej to complete installation

# %% [markdown]
# ## Creating cell ROIs in Imagej
# Use Imagej to annotate cell locations and bud appearance timepoints on aligned FOV stacks (one for each channel collected in the experiment
#
# An experiment directory should look something like
#
# ```sh
# tree 20200221_byc_analysis
# 20200221_byc_analysis
# ├── 20200221_byc_analysis
# ├── 20200221_byc_master_index.csv
# ├── 20200221_byc_notes.txt
# └── pJC069_rpn4d
#     ├── 20200221_byc_xy00_bf_stack.tif
#     ├── 20200221_byc_xy00_dsred_stack.tif
#     ├── 20200221_byc_xy00_yfp_stack.tif
#     ├── 20200221_byc_xy01_bf_stack.tif
#     ├── 20200221_byc_xy01_dsred_stack.tif
#     └── 20200221_byc_xy01_yfp_stack.tif
# ```
#
# `20200221_byc_master_index.csv` is an index with a different row for each cell and information about where to find that cell's ROIs, which xy it was found in, where to find measurement .csvs etc.

# %% [markdown]
# ### Crop (tracking) ROIs
# These ROIs will be used in `byc.segmentation` to crop cells from each channel in the cell's source FOV stack and threshold a fluorescent channel chosen by the user.
#
# 1. Open a brightfield and/or fluorescent channels FOV stack(s) in Imagej
#
#
# 2. To create a crop ROI, draw a rectangular selection around the mother cell to be tracked and press t to add it to RoiManager
#
#
# 3. Each ROI should have the mother cell approximately centered and should exclude any other cells in the same catch tube.
#
#
# 4. First ROI should be when cell first appears in experiment
#
#
# 5. Make a new ROI every time the cell moves out of the center of the ROI (whether because a division moves it or a registration issue)
#
#
# 6. Last ROI should be either last frame cell was seen alive, or whenever the user wants to end trace
#
#
# 7. Once you've finished adding crop ROIs to RoiManager, press l to focus the Imagej search bar, then type 'save cell roi set'. Type 'crop' for roi set type and whatever the end event type was. Information about this cell then gets added to the results table and you can do what you want with that. I will eventually merge these results with the `master_index.csv` to streamline information gathering
#
# The `save_cell_roi_set.py` plugin will save the crop set in the active image directory with:
#
# ```python
# roi_set_fn = '{}_cell{}_{}_rois'.format(expt_title, cell_index, roi_set_type)
# ```
#
# `cell_index` is a three digit number (eg 001) generated by looking in the active image directory, and counting the number of `.roi` or `.zip` (ROI format) files in that directory. So if you have bud or measurement ROI.zip or ROI.roi files in that directory you should temporarily move them out so that the cell count is accurate.

# %% [markdown]
# ### Measurement (cell outline) ROIs
# Use python to crop crop ROIs out of each channel FOV stack and threshold the fluorescent channel used for segmentation. Then open the cropped cell stack's in Imagej and run more imagejpc plugins to segment the cell outline and save fluorescence measurements.
#
# If you've made crop ROIs for one cell (steps above), then your experiment directory should now look like:
#
# ```sh
# tree 20200221_byc_analysis
# 20200221_byc_analysis/
# ├── 20200221_byc_analysis
# ├── 20200221_byc_master_index.csv
# ├── 20200221_byc_notes.txt
# └── pJC069_rpn4d
#     ├── 20200221_byc_cell000_crop_rois.zip
#     ├── 20200221_byc_xy00_bf_stack.tif
#     ├── 20200221_byc_xy00_cell000_bf_stack.tif
#     ├── 20200221_byc_xy00_cell000_dsred_otsu_stack.tif
#     ├── 20200221_byc_xy00_cell000_dsred_stack.tif
#     ├── 20200221_byc_xy00_cell000_yfp_stack.tif
#     ├── 20200221_byc_xy00_dsred_stack.tif
#     ├── 20200221_byc_xy00_yfp_stack.tif
#     ├── 20200221_byc_xy01_bf_stack.tif
#     ├── 20200221_byc_xy01_dsred_stack.tif
#     └── 20200221_byc_xy01_yfp_stack.tif
# ```
#
# #### Workflow for creating measurement ROIs:
#
# 1. Open each cell stack in imagej, eg:
#     * 20200221_byc_xy00_cell000_bf_stack.tif
#     * 20200221_byc_xy00_cell000_dsred_otsu_stack.tif
#     * 20200221_byc_xy00_cell000_dsred_stack.tif
#     * 20200221_byc_xy00_cell000_yfp_stack.tif
#
#
# 2. Tab to the otsu thresholded cell stack (binary image) and press g, select Method: Default, Background: Default, and check no boxes, then press enter. Cell area should black and background should be white.
#
#
# 3. Then use Imagej's Analyze Particles functionality to find cell area using the otsu thresholded cell stack (this should be rolled into a script):
#     * Press 8 to run Watershed
#     * Press q to Set Measurements. Make sure Area, integrated density, Mean gray value, Perimeter, Fit ellipse, Feret's diameter, Median, Stack position, and Display label are all checked. Then hit OK.
#     * Press u to Analyze Particles. Typically set Size to 70-1000 pixels if 60X objective. Circularity 0.55-1.00. Show nothing. Check only Add to Manager. Hit OK
#
#
# 4. Make sure there's an ROI for the first and last frame. Make sure that there are ROIs for each significant position and size/shape change of the cell so that interpolation will actually stay with the cell. Draw any new ROIs manually or use the shape from next ROI and add to RoiManager by pressing t. You should have something like this (but not necessarily an ROI for every frame):
#
# <img src="https://www.dropbox.com/s/4wb3v6cj6489rz7/194686.png?raw=true" width=400/>
#
#
# 5. Press l to focus the search bar and run 'save rois'. `save_rois.py` will sort the ROIs, make sure there's an ROI at first and last frame, then interpolate the ROIs. Then it will check if any frames have > 1 ROI. If not, the ROI set will be saved according to the active image title
#
#
# 6. Once you've successfully saved an roi set using 'save rois', the cell stacks are ready to measure. Focus the search bar with l then type 'measure rois'. `measure_rois.py` will make and save meausurements automatically.
#
# The experiment directory should now look like:
#
# ```sh
# 20200221_byc_analysis/
# ├── 20200221_byc_master_index.csv
# ├── 20200221_byc_notes.txt
# └── pJC069_rpn4d
#     ├── 20200221_byc_cell000_crop_rois.zip
#     ├── 20200221_byc_xy00_bf_stack.csv
#     ├── 20200221_byc_xy00_bf_stack.tif
#     ├── 20200221_byc_xy00_cell000_bf_stack.csv
#     ├── 20200221_byc_xy00_cell000_bf_stack.tif
#     ├── 20200221_byc_xy00_cell000_bf_stack_measurement_rois.zip
#     ├── 20200221_byc_xy00_cell000_dsred_otsu_stack.tif
#     ├── 20200221_byc_xy00_cell000_dsred_stack.csv
#     ├── 20200221_byc_xy00_cell000_dsred_stack.tif
#     ├── 20200221_byc_xy00_cell000_yfp_stack.csv
#     ├── 20200221_byc_xy00_cell000_yfp_stack.tif
#     ├── 20200221_byc_xy00_dsred_stack.tif
#     ├── 20200221_byc_xy00_yfp_stack.tif
#     ├── 20200221_byc_xy01_bf_stack.tif
#     ├── 20200221_byc_xy01_dsred_stack.tif
#     └── 20200221_byc_xy01_yfp_stack.tif
# ```

# %% [markdown]
# ### Bud ROIs
#
# Bud ROIs are created to manually track the timepoint (frame number) when daughter cells are born from a tracked mother
#
# #### Workflow for creating Bud ROIs
#
# 1. Open a brightfield FOV stack in Imagej
#
#
# 2. Draw a rectangular selection around the cell. Press t to add the selection to RoiManager as an ROI
#
#
# 3. First ROI should be the first frame in which the mother cell being tracked appears
#
#
# 4. Intermediate ROIs should be the frame at which a bud first emerges from the mother cell or the frame before
#
#
# 5. Last ROI should be the frame the mother on which the mother was last seen alive
#
#
# 6. Press l to focus the Imagej search bar. Type 'save cell roi set' and press enter. Imagej will ask for end event type which can be:
#     * 'death'
#     * 'escape'
#     * 'sen' (Means the cell appeared senescent (produced its last daughter cell) at the end of data collection but still hasn't lysed)
#
# The `save_cell_roi_set.py` plugin will then save the bud roi set in the active image directory

# %% [markdown]
# # Works in progress

# %% [markdown]
# ## Segmenting cells using peaks in intensity rays drawn outward from the center of the cell

# %%
import os
import re
import shutil

from importlib import reload

import numpy as np
import pandas as pd
import skimage
from scipy.signal import find_peaks

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.lines import Line2D
import seaborn as sns

import tifffile
from read_roi import read_roi_file, read_roi_zip

plt.style.use('default')
matplotlib.rcParams['font.sans-serif'] = 'Arial'

from byc import process, registration, constants, trace_tools, fitting_tools
from byc import files
from byc import standard_analysis as sa
from byc.segmentation import radial_avg_intensity
for mod in [process, registration, constants,
            trace_tools, fitting_tools, sa,
            files]:
    reload(mod)

# %% [markdown]
# ### Read in dataset, cell crop ROIs, etc.

# %%
WT_mdf_path = r"C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase_master_index.csv"
WT_mdf = pd.read_csv(WT_mdf_path)
rpn4d_mdf_path = r"C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase_master_index.csv"
rpn4d_mdf = pd.read_csv(rpn4d_mdf_path)

wt_ds = sa.bycDataSet(mdf=WT_mdf)
wt_trace_dfs = wt_ds.cell_trace_dfs

rpn4d_ds = sa.bycDataSet(mdf=rpn4d_mdf)
rpn4d_trace_dfs = rpn4d_ds.cell_trace_dfs
# Out:
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell000_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell001_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_rfp_otsu_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell003_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell004_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell005_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell006_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell007_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell008_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell008_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell009_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell009_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell000_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell001_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell002_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell003_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell004_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell005_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell006_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell007_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell008_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell008_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell009_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell009_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell009_crop_rois.zip

# %%
# hard coded cell crop ROI details
cell_index = 0
compartment_dir = wt_ds.master_index_df.compartment_dir.iloc[cell_index]
rois_fn = "20210126_byc_cell000_crop_rois.zip"
rois_path = os.path.join(compartment_dir, rois_fn)
# Read the ROI and the original brightfield FOV stack

bf_stack_path = wt_ds.master_index_df.active_imp_path.iloc[cell_index]
bf_stack = skimage.io.imread(bf_stack_path)

rois_df = files.read_rectangular_rois_as_df(rois_path)

# %%
for index in rois_df.index:
    if index < np.max(rois_df.index):
        position_max = rois_df.loc[index+1, 'position'] - 1
    else:
        position_max = rois_df.loc[index,'position']
        
    rois_df.loc[index, 'position_max'] = int(position_max)

# %% [markdown]
# ### Find center of the cell using above crop roi data and plot

# %%
i = 0
cellcrops = []
x_centers = []
y_centers = []
x_centers_rel = []
y_centers_rel = []
radial_dists = []
intensities = []
peak_radii = []
for frame in bf_stack:
    position = i + 1
    # Find the appropriate ROI to use to find
    # the center of the cell on this frame
    for index in rois_df.index:
        lower = int(rois_df.loc[index, 'position'])
        upper = int(rois_df.loc[index, 'position_max'])
        roi_position_range = range(lower, upper+1, 1)
        if position in roi_position_range:
            print(f'Using crop ROI with position range {roi_position_range}')
            print(f'for position {position}')
            position_to_use = lower
    
    roi_row = rois_df.set_index('position').loc[position_to_use, :]
    # Center of cell within whole FOV frame
    x_lower = roi_row.left
    x_upper = x_lower + roi_row.width
    x_center = x_lower + roi_row.width/2
    y_lower = roi_row.top
    y_center = y_lower + roi_row.height/2
    y_upper = y_lower + roi_row.height
    # Center of cell within cropped frame
    cellcrop = frame[y_lower:y_upper, x_lower:x_upper]
    cellcrops.append(cellcrop)
    x_center_rel = x_center - x_lower
    y_center_rel = y_center - y_lower
    
    x_centers.append(x_center)
    y_centers.append(y_center)
    x_centers_rel.append(x_center_rel)
    y_centers_rel.append(y_center_rel)
    print(f'Finding radial intensities at frame position {position}')
    rad, intensity = radial_avg_intensity(cellcrop,
                                          x_center_rel,
                                          y_center_rel)
    radial_dists.append(rad)
    intensities.append(intensity)
    
    peaks = find_peaks(intensity, height=np.array([300, None]))
    print(peaks)
    peak_radius = peaks[0][0]
    peak_radii.append(peak_radius)
    print(peaks)
    i += 1
# Out:
# Using crop ROI with position range range(1, 39)
# for position 1
# Finding radial intensities at frame position 1
# (array([ 4, 10, 19, 28], dtype=int64), {'peak_heights': array([1232.26666667, 1541.82857143, 1407.23305085, 1312.5       ])})
# (array([ 4, 10, 19, 28], dtype=int64), {'peak_heights': array([1232.26666667, 1541.82857143, 1407.23305085, 1312.5       ])})
# Using crop ROI with position range range(1, 39)
# for position 2
# Finding radial intensities at frame position 2
# (array([10, 19], dtype=int64), {'peak_heights': array([1553.80714286, 1390.09322034])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1553.80714286, 1390.09322034])})
# Using crop ROI with position range range(1, 39)
# for position 3
# Finding radial intensities at frame position 3
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1186.11666667, 1561.87857143, 1400.16949153])})
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1186.11666667, 1561.87857143, 1400.16949153])})
# Using crop ROI with position range range(1, 39)
# for position 4
# Finding radial intensities at frame position 4
# (array([10, 19], dtype=int64), {'peak_heights': array([1524.37857143, 1388.75423729])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1524.37857143, 1388.75423729])})
# Using crop ROI with position range range(1, 39)
# for position 5
# Finding radial intensities at frame position 5
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1372.45833333, 1483.28378378, 1373.82608696])})
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1372.45833333, 1483.28378378, 1373.82608696])})
# Using crop ROI with position range range(1, 39)
# for position 6
# Finding radial intensities at frame position 6
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1339.91666667, 1450.22972973, 1387.58385093])})
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1339.91666667, 1450.22972973, 1387.58385093])})
# Using crop ROI with position range range(1, 39)
# for position 7
# Finding radial intensities at frame position 7
# (array([ 2, 11, 22], dtype=int64), {'peak_heights': array([1278.44444444, 1424.81081081, 1373.30434783])})
# (array([ 2, 11, 22], dtype=int64), {'peak_heights': array([1278.44444444, 1424.81081081, 1373.30434783])})
# Using crop ROI with position range range(1, 39)
# for position 8
# Finding radial intensities at frame position 8
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1310.47222222, 1419.82432432, 1379.52331606])})
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1310.47222222, 1419.82432432, 1379.52331606])})
# Using crop ROI with position range range(1, 39)
# for position 9
# Finding radial intensities at frame position 9
# (array([11, 16, 21], dtype=int64), {'peak_heights': array([1440.07432432, 1235.53773585, 1377.95336788])})
# (array([11, 16, 21], dtype=int64), {'peak_heights': array([1440.07432432, 1235.53773585, 1377.95336788])})
# Using crop ROI with position range range(1, 39)
# for position 10
# Finding radial intensities at frame position 10
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1357.91666667, 1426.25675676, 1375.8136646 ])})
# (array([ 1, 11, 22], dtype=int64), {'peak_heights': array([1357.91666667, 1426.25675676, 1375.8136646 ])})
# Using crop ROI with position range range(1, 39)
# for position 11
# Finding radial intensities at frame position 11
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1322.75      , 1410.94594595, 1241.73584906, 1388.09326425])})
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1322.75      , 1410.94594595, 1241.73584906, 1388.09326425])})
# Using crop ROI with position range range(1, 39)
# for position 12
# Finding radial intensities at frame position 12
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1301.20833333, 1404.5       , 1242.95754717, 1384.08290155])})
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1301.20833333, 1404.5       , 1242.95754717, 1384.08290155])})
# Using crop ROI with position range range(1, 39)
# for position 13
# Finding radial intensities at frame position 13
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1337.33333333, 1403.45945946, 1244.53773585, 1375.1761658 ])})
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1337.33333333, 1403.45945946, 1244.53773585, 1375.1761658 ])})
# Using crop ROI with position range range(1, 39)
# for position 14
# Finding radial intensities at frame position 14
# (array([ 2, 11, 16, 21], dtype=int64), {'peak_heights': array([1337.52777778, 1398.95945946, 1242.91037736, 1396.34715026])})
# (array([ 2, 11, 16, 21], dtype=int64), {'peak_heights': array([1337.52777778, 1398.95945946, 1242.91037736, 1396.34715026])})
# Using crop ROI with position range range(1, 39)
# for position 15
# Finding radial intensities at frame position 15
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1372.41666667, 1418.2027027 , 1250.77830189, 1398.35751295])})
# (array([ 1, 11, 16, 21], dtype=int64), {'peak_heights': array([1372.41666667, 1418.2027027 , 1250.77830189, 1398.35751295])})
# Using crop ROI with position range range(1, 39)
# for position 16
# Finding radial intensities at frame position 16
# (array([11, 16, 21], dtype=int64), {'peak_heights': array([1405.97972973, 1242.25943396, 1392.81865285])})
# (array([11, 16, 21], dtype=int64), {'peak_heights': array([1405.97972973, 1242.25943396, 1392.81865285])})
# Using crop ROI with position range range(1, 39)
# for position 17
# Finding radial intensities at frame position 17
# (array([ 2, 11, 16, 21], dtype=int64), {'peak_heights': array([1376.38888889, 1392.05405405, 1249.55660377, 1390.78238342])})
# (array([ 2, 11, 16, 21], dtype=int64), {'peak_heights': array([1376.38888889, 1392.05405405, 1249.55660377, 1390.78238342])})
# Using crop ROI with position range range(1, 39)
# for position 18
# Finding radial intensities at frame position 18
# (array([ 4, 11, 21], dtype=int64), {'peak_heights': array([1263.63333333, 1381.50675676, 1392.87046632])})
# (array([ 4, 11, 21], dtype=int64), {'peak_heights': array([1263.63333333, 1381.50675676, 1392.87046632])})
# Using crop ROI with position range range(1, 39)
# for position 19
# Finding radial intensities at frame position 19
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1315.58333333, 1385.11486486, 1393.48186528])})
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1315.58333333, 1385.11486486, 1393.48186528])})
# Using crop ROI with position range range(1, 39)
# for position 20
# Finding radial intensities at frame position 20
# (array([11, 21], dtype=int64), {'peak_heights': array([1379.58783784, 1389.10880829])})
# (array([11, 21], dtype=int64), {'peak_heights': array([1379.58783784, 1389.10880829])})
# Using crop ROI with position range range(1, 39)
# for position 21
# Finding radial intensities at frame position 21
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1337.88888889, 1393.38513514, 1397.34196891])})
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1337.88888889, 1393.38513514, 1397.34196891])})
# Using crop ROI with position range range(1, 39)
# for position 22
# Finding radial intensities at frame position 22
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1316.45833333, 1388.12837838, 1389.47668394])})
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1316.45833333, 1388.12837838, 1389.47668394])})
# Using crop ROI with position range range(1, 39)
# for position 23
# Finding radial intensities at frame position 23
# (array([10, 21], dtype=int64), {'peak_heights': array([1379.94285714, 1396.2642487 ])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1379.94285714, 1396.2642487 ])})
# Using crop ROI with position range range(1, 39)
# for position 24
# Finding radial intensities at frame position 24
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1307.63888889, 1402.34459459, 1382.03108808])})
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1307.63888889, 1402.34459459, 1382.03108808])})
# Using crop ROI with position range range(1, 39)
# for position 25
# Finding radial intensities at frame position 25
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1345.77777778, 1391.82432432, 1376.31088083])})
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1345.77777778, 1391.82432432, 1376.31088083])})
# Using crop ROI with position range range(1, 39)
# for position 26
# Finding radial intensities at frame position 26
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1293.72222222, 1402.93243243, 1373.97927461])})
# (array([ 2, 11, 21], dtype=int64), {'peak_heights': array([1293.72222222, 1402.93243243, 1373.97927461])})
# Using crop ROI with position range range(1, 39)
# for position 27
# Finding radial intensities at frame position 27
# (array([ 2, 11, 19, 21], dtype=int64), {'peak_heights': array([1291.52777778, 1412.00675676, 1370.36016949, 1373.43005181])})
# (array([ 2, 11, 19, 21], dtype=int64), {'peak_heights': array([1291.52777778, 1412.00675676, 1370.36016949, 1373.43005181])})
# Using crop ROI with position range range(1, 39)
# for position 28
# Finding radial intensities at frame position 28
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1297.        , 1422.94594595, 1368.4507772 ])})
# (array([ 1, 11, 21], dtype=int64), {'peak_heights': array([1297.        , 1422.94594595, 1368.4507772 ])})
# Using crop ROI with position range range(1, 39)
# for position 29
# Finding radial intensities at frame position 29
# (array([ 1, 11, 19], dtype=int64), {'peak_heights': array([1273.66666667, 1415.00675676, 1377.53813559])})
# (array([ 1, 11, 19], dtype=int64), {'peak_heights': array([1273.66666667, 1415.00675676, 1377.53813559])})
# Using crop ROI with position range range(1, 39)
# for position 30
# Finding radial intensities at frame position 30
# (array([ 1, 11, 19, 21], dtype=int64), {'peak_heights': array([1261.79166667, 1439.04054054, 1304.16949153, 1313.11398964])})
# (array([ 1, 11, 19, 21], dtype=int64), {'peak_heights': array([1261.79166667, 1439.04054054, 1304.16949153, 1313.11398964])})
# Using crop ROI with position range range(1, 39)
# for position 31
# Finding radial intensities at frame position 31
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1203.4       , 1447.95714286, 1329.20762712])})
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1203.4       , 1447.95714286, 1329.20762712])})
# Using crop ROI with position range range(1, 39)
# for position 32
# Finding radial intensities at frame position 32
# (array([10, 19], dtype=int64), {'peak_heights': array([1446.96428571, 1329.41101695])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1446.96428571, 1329.41101695])})
# Using crop ROI with position range range(1, 39)
# for position 33
# Finding radial intensities at frame position 33
# (array([10, 19], dtype=int64), {'peak_heights': array([1445.29285714, 1344.48305085])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1445.29285714, 1344.48305085])})
# Using crop ROI with position range range(1, 39)
# for position 34
# Finding radial intensities at frame position 34
# (array([ 1, 10, 19], dtype=int64), {'peak_heights': array([1203.625     , 1435.68571429, 1336.84322034])})
# (array([ 1, 10, 19], dtype=int64), {'peak_heights': array([1203.625     , 1435.68571429, 1336.84322034])})
# Using crop ROI with position range range(1, 39)
# for position 35
# Finding radial intensities at frame position 35
# (array([10, 19], dtype=int64), {'peak_heights': array([1414.85      , 1327.03389831])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1414.85      , 1327.03389831])})
# Using crop ROI with position range range(1, 39)
# for position 36
# Finding radial intensities at frame position 36
# (array([ 3, 10, 19], dtype=int64), {'peak_heights': array([1219.90384615, 1391.77142857, 1319.36440678])})
# (array([ 3, 10, 19], dtype=int64), {'peak_heights': array([1219.90384615, 1391.77142857, 1319.36440678])})
# Using crop ROI with position range range(1, 39)
# for position 37
# Finding radial intensities at frame position 37
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1250.71666667, 1388.88571429, 1315.98305085])})
# (array([ 4, 10, 19], dtype=int64), {'peak_heights': array([1250.71666667, 1388.88571429, 1315.98305085])})
# Using crop ROI with position range range(1, 39)
# for position 38
# Finding radial intensities at frame position 38
# (array([10, 19], dtype=int64), {'peak_heights': array([1408.8       , 1311.62288136])})
# (array([10, 19], dtype=int64), {'peak_heights': array([1408.8       , 1311.62288136])})
# Using crop ROI with position range range(39, 55)
# for position 39
# Finding radial intensities at frame position 39
# (array([ 7, 18], dtype=int64), {'peak_heights': array([1401.54166667, 1343.8125    ])})
# (array([ 7, 18], dtype=int64), {'peak_heights': array([1401.54166667, 1343.8125    ])})
# Using crop ROI with position range range(39, 55)
# for position 40
# Finding radial intensities at frame position 40
# (array([ 6, 17, 19], dtype=int64), {'peak_heights': array([1405.04545455, 1325.11607143, 1324.29237288])})
# (array([ 6, 17, 19], dtype=int64), {'peak_heights': array([1405.04545455, 1325.11607143, 1324.29237288])})
# Using crop ROI with position range range(39, 55)
# for position 41
# Finding radial intensities at frame position 41
# (array([ 7, 15, 21], dtype=int64), {'peak_heights': array([1439.64583333, 1329.70673077, 1274.6373057 ])})
# (array([ 7, 15, 21], dtype=int64), {'peak_heights': array([1439.64583333, 1329.70673077, 1274.6373057 ])})
# Using crop ROI with position range range(39, 55)
# for position 42
# Finding radial intensities at frame position 42
# (array([ 6, 16, 22], dtype=int64), {'peak_heights': array([1438.82954545, 1353.50943396, 1268.93167702])})
# (array([ 6, 16, 22], dtype=int64), {'peak_heights': array([1438.82954545, 1353.50943396, 1268.93167702])})
# Using crop ROI with position range range(39, 55)
# for position 43
# Finding radial intensities at frame position 43
# (array([ 6, 17], dtype=int64), {'peak_heights': array([1420.57954545, 1348.54017857])})
# (array([ 6, 17], dtype=int64), {'peak_heights': array([1420.57954545, 1348.54017857])})
# Using crop ROI with position range range(39, 55)
# for position 44
# Finding radial intensities at frame position 44
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1443.21875   , 1382.79017857])})
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1443.21875   , 1382.79017857])})
# Using crop ROI with position range range(39, 55)
# for position 45
# Finding radial intensities at frame position 45
# (array([ 4,  8, 16], dtype=int64), {'peak_heights': array([1336.55      , 1361.68965517, 1380.12264151])})
# (array([ 4,  8, 16], dtype=int64), {'peak_heights': array([1336.55      , 1361.68965517, 1380.12264151])})
# Using crop ROI with position range range(39, 55)
# for position 46
# Finding radial intensities at frame position 46
# (array([ 8, 17], dtype=int64), {'peak_heights': array([1420.05172414, 1397.52232143])})
# (array([ 8, 17], dtype=int64), {'peak_heights': array([1420.05172414, 1397.52232143])})
# Using crop ROI with position range range(39, 55)
# for position 47
# Finding radial intensities at frame position 47
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1432.22916667, 1409.63839286])})
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1432.22916667, 1409.63839286])})
# Using crop ROI with position range range(39, 55)
# for position 48
# Finding radial intensities at frame position 48
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1435.65625   , 1425.32589286])})
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1435.65625   , 1425.32589286])})
# Using crop ROI with position range range(39, 55)
# for position 49
# Finding radial intensities at frame position 49
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1443.73958333, 1390.90178571])})
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1443.73958333, 1390.90178571])})
# Using crop ROI with position range range(39, 55)
# for position 50
# Finding radial intensities at frame position 50
# (array([ 8, 17, 21], dtype=int64), {'peak_heights': array([1419.42241379, 1356.55357143, 1299.4507772 ])})
# (array([ 8, 17, 21], dtype=int64), {'peak_heights': array([1419.42241379, 1356.55357143, 1299.4507772 ])})
# Using crop ROI with position range range(39, 55)
# for position 51
# Finding radial intensities at frame position 51
# (array([ 8, 16], dtype=int64), {'peak_heights': array([1427.0862069 , 1357.36792453])})
# (array([ 8, 16], dtype=int64), {'peak_heights': array([1427.0862069 , 1357.36792453])})
# Using crop ROI with position range range(39, 55)
# for position 52
# Finding radial intensities at frame position 52
# (array([ 8, 16], dtype=int64), {'peak_heights': array([1428.43965517, 1408.84433962])})
# (array([ 8, 16], dtype=int64), {'peak_heights': array([1428.43965517, 1408.84433962])})
# Using crop ROI with position range range(39, 55)
# for position 53
# Finding radial intensities at frame position 53
# (array([ 7, 16, 20], dtype=int64), {'peak_heights': array([1424.17708333, 1340.98584906, 1297.28440367])})
# (array([ 7, 16, 20], dtype=int64), {'peak_heights': array([1424.17708333, 1340.98584906, 1297.28440367])})
# Using crop ROI with position range range(39, 55)
# for position 54
# Finding radial intensities at frame position 54
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1441.8125    , 1337.17857143])})
# (array([ 7, 17], dtype=int64), {'peak_heights': array([1441.8125    , 1337.17857143])})
# Using crop ROI with position range range(55, 56)
# for position 55
# Finding radial intensities at frame position 55
# (array([ 1,  8, 18], dtype=int64), {'peak_heights': array([1206.95833333, 1440.56034483, 1330.92083333])})
# (array([ 1,  8, 18], dtype=int64), {'peak_heights': array([1206.95833333, 1440.56034483, 1330.92083333])})
# Using crop ROI with position range range(56, 90)
# for position 56
# Finding radial intensities at frame position 56
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1473.28571429, 1282.41509434, 1267.2484472 ])})
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1473.28571429, 1282.41509434, 1267.2484472 ])})
# Using crop ROI with position range range(56, 90)
# for position 57
# Finding radial intensities at frame position 57
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1497.84285714, 1297.47641509, 1256.60248447])})
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1497.84285714, 1297.47641509, 1256.60248447])})
# Using crop ROI with position range range(56, 90)
# for position 58
# Finding radial intensities at frame position 58
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1509.33571429, 1286.41509434, 1255.01863354])})
# (array([10, 16, 22], dtype=int64), {'peak_heights': array([1509.33571429, 1286.41509434, 1255.01863354])})
# Using crop ROI with position range range(56, 90)
# for position 59
# Finding radial intensities at frame position 59
# (array([ 1, 10, 16, 22], dtype=int64), {'peak_heights': array([1265.45833333, 1539.06428571, 1286.87264151, 1246.75776398])})
# (array([ 1, 10, 16, 22], dtype=int64), {'peak_heights': array([1265.45833333, 1539.06428571, 1286.87264151, 1246.75776398])})
# Using crop ROI with position range range(56, 90)
# for position 60
# Finding radial intensities at frame position 60
# (array([ 1, 10, 16, 22], dtype=int64), {'peak_heights': array([1245.66666667, 1520.26428571, 1292.6745283 , 1258.22360248])})
# (array([ 1, 10, 16, 22], dtype=int64), {'peak_heights': array([1245.66666667, 1520.26428571, 1292.6745283 , 1258.22360248])})
# Using crop ROI with position range range(56, 90)
# for position 61
# Finding radial intensities at frame position 61
# (array([ 3, 13, 22], dtype=int64), {'peak_heights': array([1238.03846154, 1431.87790698, 1352.42236025])})
# (array([ 3, 13, 22], dtype=int64), {'peak_heights': array([1238.03846154, 1431.87790698, 1352.42236025])})
# Using crop ROI with position range range(56, 90)
# for position 62
# Finding radial intensities at frame position 62
# (array([ 2, 13, 21], dtype=int64), {'peak_heights': array([1280.77777778, 1438.02325581, 1350.9119171 ])})
# (array([ 2, 13, 21], dtype=int64), {'peak_heights': array([1280.77777778, 1438.02325581, 1350.9119171 ])})
# Using crop ROI with position range range(56, 90)
# for position 63
# Finding radial intensities at frame position 63
# (array([ 7, 13, 21], dtype=int64), {'peak_heights': array([1335.32291667, 1439.21511628, 1340.69430052])})
# (array([ 7, 13, 21], dtype=int64), {'peak_heights': array([1335.32291667, 1439.21511628, 1340.69430052])})
# Using crop ROI with position range range(56, 90)
# for position 64
# Finding radial intensities at frame position 64
# (array([ 4,  9, 13, 22], dtype=int64), {'peak_heights': array([1253.13333333, 1374.3671875 , 1405.0872093 , 1330.51552795])})
# (array([ 4,  9, 13, 22], dtype=int64), {'peak_heights': array([1253.13333333, 1374.3671875 , 1405.0872093 , 1330.51552795])})
# Using crop ROI with position range range(56, 90)
# for position 65
# Finding radial intensities at frame position 65
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1246.7       , 1358.21875   , 1399.75      , 1334.93782383])})
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1246.7       , 1358.21875   , 1399.75      , 1334.93782383])})
# Using crop ROI with position range range(56, 90)
# for position 66
# Finding radial intensities at frame position 66
# (array([ 3, 13, 21], dtype=int64), {'peak_heights': array([1240.21153846, 1441.75      , 1361.9015544 ])})
# (array([ 3, 13, 21], dtype=int64), {'peak_heights': array([1240.21153846, 1441.75      , 1361.9015544 ])})
# Using crop ROI with position range range(56, 90)
# for position 67
# Finding radial intensities at frame position 67
# (array([ 4,  9, 13, 22], dtype=int64), {'peak_heights': array([1237.78333333, 1370.1953125 , 1418.04069767, 1347.45962733])})
# (array([ 4,  9, 13, 22], dtype=int64), {'peak_heights': array([1237.78333333, 1370.1953125 , 1418.04069767, 1347.45962733])})
# Using crop ROI with position range range(56, 90)
# for position 68
# Finding radial intensities at frame position 68
# (array([ 9, 13, 21], dtype=int64), {'peak_heights': array([1399.15625   , 1408.51162791, 1350.8238342 ])})
# (array([ 9, 13, 21], dtype=int64), {'peak_heights': array([1399.15625   , 1408.51162791, 1350.8238342 ])})
# Using crop ROI with position range range(56, 90)
# for position 69
# Finding radial intensities at frame position 69
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1235.78333333, 1368.7421875 , 1399.94767442, 1352.76165803])})
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1235.78333333, 1368.7421875 , 1399.94767442, 1352.76165803])})
# Using crop ROI with position range range(56, 90)
# for position 70
# Finding radial intensities at frame position 70
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1268.93333333, 1354.1953125 , 1391.70348837, 1363.0880829 ])})
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1268.93333333, 1354.1953125 , 1391.70348837, 1363.0880829 ])})
# Using crop ROI with position range range(56, 90)
# for position 71
# Finding radial intensities at frame position 71
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1227.96666667, 1412.03125   , 1354.83139535, 1349.13989637])})
# (array([ 4,  9, 13, 21], dtype=int64), {'peak_heights': array([1227.96666667, 1412.03125   , 1354.83139535, 1349.13989637])})
# Using crop ROI with position range range(56, 90)
# for position 72
# Finding radial intensities at frame position 72
# (array([ 3, 10, 13, 21], dtype=int64), {'peak_heights': array([1233.86538462, 1424.24285714, 1348.04651163, 1356.29015544])})
# (array([ 3, 10, 13, 21], dtype=int64), {'peak_heights': array([1233.86538462, 1424.24285714, 1348.04651163, 1356.29015544])})
# Using crop ROI with position range range(56, 90)
# for position 73
# Finding radial intensities at frame position 73
# (array([ 1, 10, 22], dtype=int64), {'peak_heights': array([1248.91666667, 1447.70714286, 1349.47826087])})
# (array([ 1, 10, 22], dtype=int64), {'peak_heights': array([1248.91666667, 1447.70714286, 1349.47826087])})
# Using crop ROI with position range range(56, 90)
# for position 74
# Finding radial intensities at frame position 74
# (array([10, 21], dtype=int64), {'peak_heights': array([1439.03571429, 1377.1761658 ])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1439.03571429, 1377.1761658 ])})
# Using crop ROI with position range range(56, 90)
# for position 75
# Finding radial intensities at frame position 75
# (array([10, 21], dtype=int64), {'peak_heights': array([1437.37857143, 1367.40414508])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1437.37857143, 1367.40414508])})
# Using crop ROI with position range range(56, 90)
# for position 76
# Finding radial intensities at frame position 76
# (array([10, 21], dtype=int64), {'peak_heights': array([1462.21428571, 1364.66321244])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1462.21428571, 1364.66321244])})
# Using crop ROI with position range range(56, 90)
# for position 77
# Finding radial intensities at frame position 77
# (array([10, 21], dtype=int64), {'peak_heights': array([1453.49285714, 1364.44559585])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1453.49285714, 1364.44559585])})
# Using crop ROI with position range range(56, 90)
# for position 78
# Finding radial intensities at frame position 78
# (array([ 4, 10, 21], dtype=int64), {'peak_heights': array([1191.66666667, 1455.73571429, 1357.65803109])})
# (array([ 4, 10, 21], dtype=int64), {'peak_heights': array([1191.66666667, 1455.73571429, 1357.65803109])})
# Using crop ROI with position range range(56, 90)
# for position 79
# Finding radial intensities at frame position 79
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1171.66666667, 1470.50714286, 1322.80829016])})
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1171.66666667, 1470.50714286, 1322.80829016])})
# Using crop ROI with position range range(56, 90)
# for position 80
# Finding radial intensities at frame position 80
# (array([10, 21], dtype=int64), {'peak_heights': array([1478.59285714, 1321.79274611])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1478.59285714, 1321.79274611])})
# Using crop ROI with position range range(56, 90)
# for position 81
# Finding radial intensities at frame position 81
# (array([ 2, 10, 20], dtype=int64), {'peak_heights': array([1176.83333333, 1494.93571429, 1361.67889908])})
# (array([ 2, 10, 20], dtype=int64), {'peak_heights': array([1176.83333333, 1494.93571429, 1361.67889908])})
# Using crop ROI with position range range(56, 90)
# for position 82
# Finding radial intensities at frame position 82
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1180.19444444, 1519.17142857, 1432.07253886])})
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1180.19444444, 1519.17142857, 1432.07253886])})
# Using crop ROI with position range range(56, 90)
# for position 83
# Finding radial intensities at frame position 83
# (array([ 1, 10, 21], dtype=int64), {'peak_heights': array([1177.70833333, 1490.22857143, 1412.01036269])})
# (array([ 1, 10, 21], dtype=int64), {'peak_heights': array([1177.70833333, 1490.22857143, 1412.01036269])})
# Using crop ROI with position range range(56, 90)
# for position 84
# Finding radial intensities at frame position 84
# (array([ 2, 10, 20], dtype=int64), {'peak_heights': array([1194.30555556, 1503.01428571, 1366.21100917])})
# (array([ 2, 10, 20], dtype=int64), {'peak_heights': array([1194.30555556, 1503.01428571, 1366.21100917])})
# Using crop ROI with position range range(56, 90)
# for position 85
# Finding radial intensities at frame position 85
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1249.02777778, 1505.03571429, 1352.23316062])})
# (array([ 2, 10, 21], dtype=int64), {'peak_heights': array([1249.02777778, 1505.03571429, 1352.23316062])})
# Using crop ROI with position range range(56, 90)
# for position 86
# Finding radial intensities at frame position 86
# (array([ 1, 10, 20], dtype=int64), {'peak_heights': array([1328.91666667, 1512.56428571, 1323.03211009])})
# (array([ 1, 10, 20], dtype=int64), {'peak_heights': array([1328.91666667, 1512.56428571, 1323.03211009])})
# Using crop ROI with position range range(56, 90)
# for position 87
# Finding radial intensities at frame position 87
# (array([ 2, 10, 19], dtype=int64), {'peak_heights': array([1260.69444444, 1550.42142857, 1328.69915254])})
# (array([ 2, 10, 19], dtype=int64), {'peak_heights': array([1260.69444444, 1550.42142857, 1328.69915254])})
# Using crop ROI with position range range(56, 90)
# for position 88
# Finding radial intensities at frame position 88
# (array([10, 21], dtype=int64), {'peak_heights': array([1531.10714286, 1330.01036269])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1531.10714286, 1330.01036269])})
# Using crop ROI with position range range(56, 90)
# for position 89
# Finding radial intensities at frame position 89
# (array([10, 21], dtype=int64), {'peak_heights': array([1513.45714286, 1329.43005181])})
# (array([10, 21], dtype=int64), {'peak_heights': array([1513.45714286, 1329.43005181])})
# Using crop ROI with position range range(90, 91)
# for position 90
# Finding radial intensities at frame position 90
# (array([12, 22], dtype=int64), {'peak_heights': array([1432.84375   , 1322.05590062])})
# (array([12, 22], dtype=int64), {'peak_heights': array([1432.84375   , 1322.05590062])})

# %%
stack = skimage.io.concatenate_images(cellcrops)
skimage.io.imsave('test_stack.tif', stack)
# Out:
# <ipython-input-12-41f4aad7a3cf>:2: UserWarning: test_stack.tif is a low contrast image
#   skimage.io.imsave('test_stack.tif', stack)

# %%
frame = 0

fig = plt.figure(figsize=(2, 2))
fig.set_dpi(200)
ax = plt.axes()
img = bf_stack[frame]
cellcrop = img[y_lower:y_upper, x_lower:x_upper]
ax.imshow(cellcrop);

x_center_rel = x_center - x_lower
y_center_rel = y_center - y_lower
ax.scatter(x_center_rel, y_center_rel, s=10,
           color='white')

# %% [markdown]
# ### Plot average intensity against radial distance from the center of the above cell

# %%
frame = 0
img = bf_stack[frame]

# %%
mpl = matplotlib
max_distance = 30
# Adjust plot parameters
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 16
mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['xtick.major.size'] = 7
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['ytick.major.size'] = 7
mpl.rcParams['ytick.major.width'] = 2
# Create figure and add subplot
fig = plt.figure()
ax = fig.add_subplot(111)
# Plot data
ax.plot(rad, intensity, linewidth=2, color='red')
# Edit axis labels
ax.set_xlabel('Radial Distance (pixels)', labelpad=10)
ax.set_ylabel('Average Intensity (AU)', labelpad=10)
ax.set_xlim(0, max_distance)
ax.set_ylim(1000, 1600)
intensity_slice = intensity[0:max_distance+1]
intensity_slice = intensity_slice - intensity_slice.min()
peaks = find_peaks(intensity_slice, height=np.array([300, None]))[0]
# peaks[0] is the index at which the peak is found. 
# So index + 1 = actual distance
radius= peaks[0] + 1
ax.axvline(x=radius, color='black', linestyle='--')

# %% [markdown]
# **Super helpful! A normal cell width is around 25 px and that first peak is right around 12 px**

# %%
mpl = matplotlib
max_distance = 30
palette = sns.color_palette("icefire", n_colors=90)
# Adjust plot parameters
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 16
mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['xtick.major.size'] = 7
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['ytick.major.size'] = 7
mpl.rcParams['ytick.major.width'] = 2
# Create figure and add subplot
fig = plt.figure()
ax = fig.add_subplot(111)
for i, intensity in enumerate(intensities):
    # Plot data
    rad = radial_dists[i]
    ax.plot(rad, intensity, linewidth=2, color=palette[i],
            alpha=0.9)
    # Edit axis labels
    ax.set_xlabel('Radial Distance (pixels)', labelpad=10)
    ax.set_ylabel('Average Intensity (AU)', labelpad=10)
    ax.set_xlim(0, max_distance)
    
ax.set_ylim(1000, 1600)
# Out:
# (1000.0, 1600.0)

# %% [markdown]
# ### Plot a circle with radius at first peak found above

# %%
frame = 0
fig = plt.figure(figsize=(2, 2))
fig.set_dpi(200)
ax = plt.axes()
img = bf_stack[frame]
cellcrop = img[y_lower:y_upper, x_lower:x_upper]
ax.imshow(cellcrop);

x_center_rel = x_center - x_lower
y_center_rel = y_center - y_lower
ax.scatter(x_center_rel, y_center_rel, s=10,
           color='white')
circ = mpl.patches.Circle(xy=(x_center_rel, y_center_rel), radius=radius,
                          color='white', fill=False)
ax.add_patch(circ)
ax.set_xticks(np.array(range(0, cellcrop.shape[1], 10)))
ax.set_yticks(np.array(range(0, cellcrop.shape[0], 10)))
ax.set_ylabel('Y Distance (pixels)')
ax.set_xlabel('X Distance (pixels)')
# Out:
# Text(0.5, 0, 'X Distance (pixels)')

# %% [markdown]
# ### Creating polar coordinates to use in measuring intensity along rays drawn out from center

# %% [markdown]
# First, for each pixel in the image, create a 2 x N (N = # of pixels in image) of cartesian coordinates for that pixel relative to an arbitrary center point. Calcuate radial coordinate using pythagorean theoreom and theta = arctan(Y/X) for angular coordinate

# %%
from byc import segmentation
reload(segmentation)
R, theta = segmentation.get_polar_coordinates(cellcrop, 22.5, 20)

# %% [markdown]
# Select angular slice of image using polar coordinates calculated above

# %%
bin_size = np.pi/4
i = 0
min_theta = 0
max_theta = i + bin_size
mask = (np.greater(theta, min_theta) & np.less(theta, max_theta))
values = cellcrop[mask]
cellcrop_sliced = cellcrop.copy()
cellcrop_sliced[mask] = 0

fig = plt.figure()
ax = fig.add_subplot(121)
ax.imshow(cellcrop)
ax2 = fig.add_subplot(122)
ax2.imshow(cellcrop_sliced)
# Titles
ax.set_title(f'Original Image', fontsize=12)
ax2.set_title(f'{round(min_theta, 2)} to {round(max_theta, 2)} radians blacked out',
              fontsize=12)
# Out:
# Text(0.5, 1.0, '0 to 0.79 radians blacked out')

# %% [markdown]
# Calculate the mean intensity of all pixels within each theta and radial distance bin

# %%
reload(segmentation)
df = segmentation.intensity_by_distance_and_theta(cellcrop, 22.5, 20)
# Out:
# Looking for pixels at -3.141592653589793 radians, 0.0 pixels
# Looking for pixels at -3.141592653589793 radians, 1.0 pixels
# Looking for pixels at -3.141592653589793 radians, 2.0 pixels
# Looking for pixels at -3.141592653589793 radians, 3.0 pixels
# Looking for pixels at -3.141592653589793 radians, 4.0 pixels
# Looking for pixels at -3.141592653589793 radians, 5.0 pixels
# Looking for pixels at -3.141592653589793 radians, 6.0 pixels
# Looking for pixels at -3.141592653589793 radians, 7.0 pixels
# Looking for pixels at -3.141592653589793 radians, 8.0 pixels
# Looking for pixels at -3.141592653589793 radians, 9.0 pixels
# Looking for pixels at -3.141592653589793 radians, 10.0 pixels
# Looking for pixels at -3.141592653589793 radians, 11.0 pixels
# Looking for pixels at -3.141592653589793 radians, 12.0 pixels
# Looking for pixels at -3.141592653589793 radians, 13.0 pixels
# Looking for pixels at -3.141592653589793 radians, 14.0 pixels
# Looking for pixels at -3.141592653589793 radians, 15.0 pixels
# Looking for pixels at -3.141592653589793 radians, 16.0 pixels
# Looking for pixels at -3.141592653589793 radians, 17.0 pixels
# Looking for pixels at -3.141592653589793 radians, 18.0 pixels
# Looking for pixels at -3.141592653589793 radians, 19.0 pixels
# Looking for pixels at -2.945243112740431 radians, 0.0 pixels
# Looking for pixels at -2.945243112740431 radians, 1.0 pixels
# Looking for pixels at -2.945243112740431 radians, 2.0 pixels
# Looking for pixels at -2.945243112740431 radians, 3.0 pixels
# Looking for pixels at -2.945243112740431 radians, 4.0 pixels
# Looking for pixels at -2.945243112740431 radians, 5.0 pixels
# Looking for pixels at -2.945243112740431 radians, 6.0 pixels
# Looking for pixels at -2.945243112740431 radians, 7.0 pixels
# Looking for pixels at -2.945243112740431 radians, 8.0 pixels
# Looking for pixels at -2.945243112740431 radians, 9.0 pixels
# Looking for pixels at -2.945243112740431 radians, 10.0 pixels
# Looking for pixels at -2.945243112740431 radians, 11.0 pixels
# Looking for pixels at -2.945243112740431 radians, 12.0 pixels
# Looking for pixels at -2.945243112740431 radians, 13.0 pixels
# Looking for pixels at -2.945243112740431 radians, 14.0 pixels
# Looking for pixels at -2.945243112740431 radians, 15.0 pixels
# Looking for pixels at -2.945243112740431 radians, 16.0 pixels
# Looking for pixels at -2.945243112740431 radians, 17.0 pixels
# Looking for pixels at -2.945243112740431 radians, 18.0 pixels
# Looking for pixels at -2.945243112740431 radians, 19.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 0.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 1.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 2.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 3.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 4.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 5.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 6.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 7.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 8.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 9.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 10.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 11.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 12.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 13.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 14.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 15.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 16.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 17.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 18.0 pixels
# Looking for pixels at -2.7488935718910685 radians, 19.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 0.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 1.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 2.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 3.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 4.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 5.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 6.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 7.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 8.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 9.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 10.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 11.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 12.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 13.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 14.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 15.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 16.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 17.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 18.0 pixels
# Looking for pixels at -2.5525440310417062 radians, 19.0 pixels
# Looking for pixels at -2.356194490192344 radians, 0.0 pixels
# Looking for pixels at -2.356194490192344 radians, 1.0 pixels
# Looking for pixels at -2.356194490192344 radians, 2.0 pixels
# Looking for pixels at -2.356194490192344 radians, 3.0 pixels
# Looking for pixels at -2.356194490192344 radians, 4.0 pixels
# Looking for pixels at -2.356194490192344 radians, 5.0 pixels
# Looking for pixels at -2.356194490192344 radians, 6.0 pixels
# Looking for pixels at -2.356194490192344 radians, 7.0 pixels
# Looking for pixels at -2.356194490192344 radians, 8.0 pixels
# Looking for pixels at -2.356194490192344 radians, 9.0 pixels
# Looking for pixels at -2.356194490192344 radians, 10.0 pixels
# Looking for pixels at -2.356194490192344 radians, 11.0 pixels
# Looking for pixels at -2.356194490192344 radians, 12.0 pixels
# Looking for pixels at -2.356194490192344 radians, 13.0 pixels
# Looking for pixels at -2.356194490192344 radians, 14.0 pixels
# Looking for pixels at -2.356194490192344 radians, 15.0 pixels
# Looking for pixels at -2.356194490192344 radians, 16.0 pixels
# Looking for pixels at -2.356194490192344 radians, 17.0 pixels
# Looking for pixels at -2.356194490192344 radians, 18.0 pixels
# Looking for pixels at -2.356194490192344 radians, 19.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 0.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 1.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 2.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 3.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 4.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 5.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 6.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 7.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 8.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 9.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 10.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 11.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 12.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 13.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 14.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 15.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 16.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 17.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 18.0 pixels
# Looking for pixels at -2.1598449493429817 radians, 19.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 0.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 1.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 2.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 3.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 4.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 5.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 6.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 7.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 8.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 9.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 10.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 11.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 12.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 13.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 14.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 15.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 16.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 17.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 18.0 pixels
# Looking for pixels at -1.9634954084936194 radians, 19.0 pixels
# Looking for pixels at -1.767145867644257 radians, 0.0 pixels
# Looking for pixels at -1.767145867644257 radians, 1.0 pixels
# Looking for pixels at -1.767145867644257 radians, 2.0 pixels
# Looking for pixels at -1.767145867644257 radians, 3.0 pixels
# Looking for pixels at -1.767145867644257 radians, 4.0 pixels
# Looking for pixels at -1.767145867644257 radians, 5.0 pixels
# Looking for pixels at -1.767145867644257 radians, 6.0 pixels
# Looking for pixels at -1.767145867644257 radians, 7.0 pixels
# Looking for pixels at -1.767145867644257 radians, 8.0 pixels
# Looking for pixels at -1.767145867644257 radians, 9.0 pixels
# Looking for pixels at -1.767145867644257 radians, 10.0 pixels
# Looking for pixels at -1.767145867644257 radians, 11.0 pixels
# Looking for pixels at -1.767145867644257 radians, 12.0 pixels
# Looking for pixels at -1.767145867644257 radians, 13.0 pixels
# Looking for pixels at -1.767145867644257 radians, 14.0 pixels
# Looking for pixels at -1.767145867644257 radians, 15.0 pixels
# Looking for pixels at -1.767145867644257 radians, 16.0 pixels
# Looking for pixels at -1.767145867644257 radians, 17.0 pixels
# Looking for pixels at -1.767145867644257 radians, 18.0 pixels
# Looking for pixels at -1.767145867644257 radians, 19.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 0.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 1.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 2.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 3.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 4.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 5.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 6.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 7.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 8.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 9.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 10.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 11.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 12.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 13.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 14.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 15.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 16.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 17.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 18.0 pixels
# Looking for pixels at -1.5707963267948948 radians, 19.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 0.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 1.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 2.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 3.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 4.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 5.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 6.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 7.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 8.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 9.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 10.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 11.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 12.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 13.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 14.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 15.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 16.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 17.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 18.0 pixels
# Looking for pixels at -1.3744467859455325 radians, 19.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 0.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 1.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 2.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 3.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 4.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 5.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 6.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 7.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 8.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 9.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 10.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 11.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 12.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 13.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 14.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 15.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 16.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 17.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 18.0 pixels
# Looking for pixels at -1.1780972450961702 radians, 19.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 0.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 1.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 2.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 3.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 4.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 5.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 6.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 7.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 8.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 9.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 10.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 11.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 12.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 13.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 14.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 15.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 16.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 17.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 18.0 pixels
# Looking for pixels at -0.9817477042468079 radians, 19.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 0.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 1.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 2.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 3.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 4.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 5.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 6.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 7.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 8.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 9.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 10.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 11.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 12.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 13.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 14.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 15.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 16.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 17.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 18.0 pixels
# Looking for pixels at -0.7853981633974456 radians, 19.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 0.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 1.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 2.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 3.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 4.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 5.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 6.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 7.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 8.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 9.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 10.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 11.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 12.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 13.0 pixels
# C:\.byc\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\.byc\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Looking for pixels at -0.5890486225480833 radians, 14.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 15.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 16.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 17.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 18.0 pixels
# Looking for pixels at -0.5890486225480833 radians, 19.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 0.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 1.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 2.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 3.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 4.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 5.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 6.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 7.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 8.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 9.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 10.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 11.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 12.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 13.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 14.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 15.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 16.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 17.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 18.0 pixels
# Looking for pixels at -0.39269908169872103 radians, 19.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 0.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 1.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 2.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 3.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 4.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 5.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 6.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 7.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 8.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 9.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 10.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 11.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 12.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 13.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 14.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 15.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 16.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 17.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 18.0 pixels
# Looking for pixels at -0.19634954084935874 radians, 19.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 0.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 1.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 2.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 3.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 4.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 5.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 6.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 7.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 8.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 9.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 10.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 11.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 12.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 13.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 14.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 15.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 16.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 17.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 18.0 pixels
# Looking for pixels at 3.552713678800501e-15 radians, 19.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 0.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 1.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 2.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 3.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 4.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 5.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 6.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 7.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 8.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 9.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 10.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 11.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 12.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 13.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 14.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 15.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 16.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 17.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 18.0 pixels
# Looking for pixels at 0.19634954084936584 radians, 19.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 0.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 1.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 2.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 3.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 4.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 5.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 6.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 7.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 8.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 9.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 10.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 11.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 12.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 13.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 14.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 15.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 16.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 17.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 18.0 pixels
# Looking for pixels at 0.39269908169872814 radians, 19.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 0.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 1.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 2.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 3.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 4.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 5.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 6.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 7.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 8.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 9.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 10.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 11.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 12.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 13.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 14.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 15.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 16.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 17.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 18.0 pixels
# Looking for pixels at 0.5890486225480904 radians, 19.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 0.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 1.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 2.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 3.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 4.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 5.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 6.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 7.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 8.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 9.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 10.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 11.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 12.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 13.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 14.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 15.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 16.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 17.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 18.0 pixels
# Looking for pixels at 0.7853981633974527 radians, 19.0 pixels
# Looking for pixels at 0.981747704246815 radians, 0.0 pixels
# Looking for pixels at 0.981747704246815 radians, 1.0 pixels
# Looking for pixels at 0.981747704246815 radians, 2.0 pixels
# Looking for pixels at 0.981747704246815 radians, 3.0 pixels
# Looking for pixels at 0.981747704246815 radians, 4.0 pixels
# Looking for pixels at 0.981747704246815 radians, 5.0 pixels
# Looking for pixels at 0.981747704246815 radians, 6.0 pixels
# Looking for pixels at 0.981747704246815 radians, 7.0 pixels
# Looking for pixels at 0.981747704246815 radians, 8.0 pixels
# Looking for pixels at 0.981747704246815 radians, 9.0 pixels
# Looking for pixels at 0.981747704246815 radians, 10.0 pixels
# Looking for pixels at 0.981747704246815 radians, 11.0 pixels
# Looking for pixels at 0.981747704246815 radians, 12.0 pixels
# Looking for pixels at 0.981747704246815 radians, 13.0 pixels
# Looking for pixels at 0.981747704246815 radians, 14.0 pixels
# Looking for pixels at 0.981747704246815 radians, 15.0 pixels
# Looking for pixels at 0.981747704246815 radians, 16.0 pixels
# Looking for pixels at 0.981747704246815 radians, 17.0 pixels
# Looking for pixels at 0.981747704246815 radians, 18.0 pixels
# Looking for pixels at 0.981747704246815 radians, 19.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 0.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 1.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 2.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 3.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 4.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 5.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 6.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 7.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 8.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 9.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 10.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 11.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 12.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 13.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 14.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 15.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 16.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 17.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 18.0 pixels
# Looking for pixels at 1.1780972450961773 radians, 19.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 0.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 1.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 2.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 3.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 4.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 5.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 6.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 7.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 8.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 9.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 10.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 11.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 12.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 13.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 14.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 15.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 16.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 17.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 18.0 pixels
# Looking for pixels at 1.3744467859455396 radians, 19.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 0.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 1.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 2.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 3.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 4.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 5.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 6.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 7.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 8.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 9.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 10.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 11.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 12.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 13.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 14.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 15.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 16.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 17.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 18.0 pixels
# Looking for pixels at 1.5707963267949019 radians, 19.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 0.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 1.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 2.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 3.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 4.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 5.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 6.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 7.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 8.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 9.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 10.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 11.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 12.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 13.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 14.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 15.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 16.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 17.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 18.0 pixels
# Looking for pixels at 1.7671458676442642 radians, 19.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 0.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 1.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 2.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 3.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 4.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 5.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 6.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 7.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 8.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 9.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 10.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 11.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 12.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 13.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 14.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 15.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 16.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 17.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 18.0 pixels
# Looking for pixels at 1.9634954084936265 radians, 19.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 0.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 1.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 2.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 3.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 4.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 5.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 6.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 7.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 8.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 9.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 10.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 11.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 12.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 13.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 14.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 15.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 16.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 17.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 18.0 pixels
# Looking for pixels at 2.1598449493429888 radians, 19.0 pixels
# Looking for pixels at 2.356194490192351 radians, 0.0 pixels
# Looking for pixels at 2.356194490192351 radians, 1.0 pixels
# Looking for pixels at 2.356194490192351 radians, 2.0 pixels
# Looking for pixels at 2.356194490192351 radians, 3.0 pixels
# Looking for pixels at 2.356194490192351 radians, 4.0 pixels
# Looking for pixels at 2.356194490192351 radians, 5.0 pixels
# Looking for pixels at 2.356194490192351 radians, 6.0 pixels
# Looking for pixels at 2.356194490192351 radians, 7.0 pixels
# Looking for pixels at 2.356194490192351 radians, 8.0 pixels
# Looking for pixels at 2.356194490192351 radians, 9.0 pixels
# Looking for pixels at 2.356194490192351 radians, 10.0 pixels
# Looking for pixels at 2.356194490192351 radians, 11.0 pixels
# Looking for pixels at 2.356194490192351 radians, 12.0 pixels
# Looking for pixels at 2.356194490192351 radians, 13.0 pixels
# Looking for pixels at 2.356194490192351 radians, 14.0 pixels
# Looking for pixels at 2.356194490192351 radians, 15.0 pixels
# Looking for pixels at 2.356194490192351 radians, 16.0 pixels
# Looking for pixels at 2.356194490192351 radians, 17.0 pixels
# Looking for pixels at 2.356194490192351 radians, 18.0 pixels
# Looking for pixels at 2.356194490192351 radians, 19.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 0.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 1.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 2.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 3.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 4.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 5.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 6.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 7.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 8.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 9.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 10.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 11.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 12.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 13.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 14.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 15.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 16.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 17.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 18.0 pixels
# Looking for pixels at 2.5525440310417133 radians, 19.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 0.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 1.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 2.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 3.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 4.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 5.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 6.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 7.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 8.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 9.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 10.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 11.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 12.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 13.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 14.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 15.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 16.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 17.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 18.0 pixels
# Looking for pixels at 2.7488935718910756 radians, 19.0 pixels
# Looking for pixels at 2.945243112740438 radians, 0.0 pixels
# Looking for pixels at 2.945243112740438 radians, 1.0 pixels
# Looking for pixels at 2.945243112740438 radians, 2.0 pixels
# Looking for pixels at 2.945243112740438 radians, 3.0 pixels
# Looking for pixels at 2.945243112740438 radians, 4.0 pixels
# Looking for pixels at 2.945243112740438 radians, 5.0 pixels
# Looking for pixels at 2.945243112740438 radians, 6.0 pixels
# Looking for pixels at 2.945243112740438 radians, 7.0 pixels
# Looking for pixels at 2.945243112740438 radians, 8.0 pixels
# Looking for pixels at 2.945243112740438 radians, 9.0 pixels
# Looking for pixels at 2.945243112740438 radians, 10.0 pixels
# Looking for pixels at 2.945243112740438 radians, 11.0 pixels
# Looking for pixels at 2.945243112740438 radians, 12.0 pixels
# Looking for pixels at 2.945243112740438 radians, 13.0 pixels
# Looking for pixels at 2.945243112740438 radians, 14.0 pixels
# Looking for pixels at 2.945243112740438 radians, 15.0 pixels
# Looking for pixels at 2.945243112740438 radians, 16.0 pixels
# Looking for pixels at 2.945243112740438 radians, 17.0 pixels
# Looking for pixels at 2.945243112740438 radians, 18.0 pixels
# Looking for pixels at 2.945243112740438 radians, 19.0 pixels

# %%
palette = sns.color_palette("icefire", n_colors=len(df.theta.unique()))
fig = plt.figure()

ax = sns.lineplot(x='radial_distance', y='intensity', hue='theta', data=df,
             hue_order=df.theta.unique(), palette=palette)
ax.set_xlim(0, 20)
ax.set_ylim(500, 2500)
ax.set_ylabel('Intensity', fontsize=16)
ax.set_xlabel('Radial Distance from Center (px)', fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

# %% [markdown]
# ### Finding and annotating peaks

# %%
df = segmentation.polar_intensity_peaks(df)

table = df.pivot_table(index='theta', aggfunc='mean').reset_index()
table.loc[:, 'peak_X'] = table.highest_peak_dist*np.cos(table.theta) + x_center_rel
table.loc[:, 'peak_Y'] = table.highest_peak_dist*np.sin(table.theta) + y_center_rel

# %%
ax = plt.axes()
ax.imshow(cellcrop)
ax.scatter(table.peak_X, table.peak_Y, color='white')

# %%
ax = plt.axes()
ax.imshow(cellcrop)
i=0
for index in table.index:
    c = palette[i]
    x = table.loc[index, 'peak_X']
    y = table.loc[index, 'peak_Y']
    ax.scatter(x, y, color=c)
    i+=1
ax.scatter(x_center_rel, y_center_rel, color='white')

# %%
table.loc[:, 'peak_X'] = table.highest_peak_dist*np.cos(table.theta) + x_center
table.loc[:, 'peak_Y'] = table.highest_peak_dist*np.sin(table.theta) + y_center

ax = plt.axes()
ax.imshow(img)
ax.scatter(table.peak_X, table.peak_Y,
           color='white', s=0.1)

# %% [markdown]
# ## Finding radial intensity peaks in a cell stack

# %%
import os
import re
import shutil

from importlib import reload

import numpy as np
import pandas as pd
import skimage
from scipy.signal import find_peaks

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.lines import Line2D
import seaborn as sns

import tifffile
from read_roi import read_roi_file, read_roi_zip

plt.style.use('default')
matplotlib.rcParams['font.sans-serif'] = 'Arial'

from byc import process, registration, constants, trace_tools, fitting_tools
from byc import files
from byc import standard_analysis as sa
from byc.segmentation import radial_avg_intensity
for mod in [process, registration, constants,
            trace_tools, fitting_tools, sa,
            files]:
    reload(mod)

# %%
WT_mdf_path = r"C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase_master_index.csv"
WT_mdf = pd.read_csv(WT_mdf_path)
rpn4d_mdf_path = r"C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase_master_index.csv"
rpn4d_mdf = pd.read_csv(rpn4d_mdf_path)

wt_ds = sa.bycDataSet(mdf=WT_mdf)
wt_trace_dfs = wt_ds.cell_trace_dfs

rpn4d_ds = sa.bycDataSet(mdf=rpn4d_mdf)
rpn4d_trace_dfs = rpn4d_ds.cell_trace_dfs

# hard coded cell crop ROI details
cell_index = 0
compartment_dir = wt_ds.master_index_df.compartment_dir.iloc[cell_index]
rois_fn = "20210126_byc_cell000_crop_rois.zip"
rois_path = os.path.join(compartment_dir, rois_fn)
# Read the ROI and the original brightfield FOV stack
bf_stack_path = wt_ds.master_index_df.active_imp_path.iloc[cell_index]
bf_stack = skimage.io.imread(bf_stack_path)

rois_df = files.read_rectangular_rois_as_df(rois_path)
# Out:
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell000_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell001_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_rfp_otsu_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell003_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell004_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell005_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell006_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell007_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell008_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell008_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell009_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_xy00_cell009_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_BY4741_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell000_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 0 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell000_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell000_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell001_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 1 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell001_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell001_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell002_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 2 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell002_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell002_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell003_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 3 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell003_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell003_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell004_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 4 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell004_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell004_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell005_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 5 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell005_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell005_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell006_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 6 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell006_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell006_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell007_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 7 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell007_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell007_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell008_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 8 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell008_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell008_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell009_bf_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell009_crop_rois.zip
# Found data for cell 9 at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_xy03_cell009_rfp_stack.csv
# Looking for crop ROIs at C:\Users\John Cooper\Projects\byc\data\20210126_byc\20210126_byc_pJC184_rpn4d_young_chase\20210126_byc_cell009_crop_rois.zip

# %%
len(peaks_dfs)
# Out:
# 34

# %%
reload(segmentation)
# Out:
# <module 'byc.segmentation' from 'C:\\Users\\John Cooper\\Projects\\byc\\byc\\segmentation.py'>

# %%
theta_bin_size = np.pi/2
peaks_dfs = []
cellcrops = []
for frame_index, frame in enumerate(bf_stack):
    position = frame_index + 1
    print(f'Looking for cell edges in frame position {position} of {len(bf_stack)}')
    # Find which roi to use
    for index in rois_df.index:
        row = rois_df.loc[index, :]
        positions = np.arange(row.position, row.position_max+1, 1)
        if position in positions:
            good_index = index
    frame_roi_row = rois_df.loc[good_index, :]    
    x_lower = frame_roi_row.left
    x_upper = x_lower + frame_roi_row.width
    x_center = x_lower + frame_roi_row.width/2
    y_lower = frame_roi_row.top
    y_center = y_lower + frame_roi_row.height/2
    y_upper = y_lower + frame_roi_row.height
    # Center of cell within cropped frame
    cellcrop = frame[y_lower:y_upper, x_lower:x_upper]
    cellcrops.append(cellcrop)
    x_center_rel = x_center - x_lower
    y_center_rel = y_center - y_lower
    polar_I_df = segmentation.intensity_by_distance_and_theta(cellcrop,
                                                              x_center_rel,
                                                              y_center_rel,
                                                              theta_bin_size=theta_bin_size)
    peaks_df = segmentation.polar_intensity_peaks(polar_I_df)
    peaks_df.loc[:, 'frame_index'] = frame_index
    peaks_dfs.append(peaks_df)
# Out:
# Looking for cell edges in frame position 1 of 90
# Looking for cell edges in frame position 2 of 90
# Looking for cell edges in frame position 3 of 90
# C:\.byc\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\.byc\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Looking for cell edges in frame position 4 of 90
# Looking for cell edges in frame position 5 of 90
# Looking for cell edges in frame position 6 of 90
# Looking for cell edges in frame position 7 of 90
# Looking for cell edges in frame position 8 of 90
# Looking for cell edges in frame position 9 of 90
# Looking for cell edges in frame position 10 of 90
# Looking for cell edges in frame position 11 of 90
# Looking for cell edges in frame position 12 of 90
# Looking for cell edges in frame position 13 of 90
# Looking for cell edges in frame position 14 of 90
# Looking for cell edges in frame position 15 of 90
# Looking for cell edges in frame position 16 of 90
# Looking for cell edges in frame position 17 of 90
# Looking for cell edges in frame position 18 of 90
# Looking for cell edges in frame position 19 of 90
# Looking for cell edges in frame position 20 of 90
# Looking for cell edges in frame position 21 of 90
# Looking for cell edges in frame position 22 of 90
# Looking for cell edges in frame position 23 of 90
# Looking for cell edges in frame position 24 of 90
# Looking for cell edges in frame position 25 of 90
# Looking for cell edges in frame position 26 of 90
# Looking for cell edges in frame position 27 of 90
# Looking for cell edges in frame position 28 of 90
# Looking for cell edges in frame position 29 of 90
# Looking for cell edges in frame position 30 of 90
# Looking for cell edges in frame position 31 of 90
# Looking for cell edges in frame position 32 of 90
# Looking for cell edges in frame position 33 of 90
# Looking for cell edges in frame position 34 of 90
# Looking for cell edges in frame position 35 of 90
# Looking for cell edges in frame position 36 of 90
# Looking for cell edges in frame position 37 of 90
# Looking for cell edges in frame position 38 of 90
# Looking for cell edges in frame position 39 of 90
# Looking for cell edges in frame position 40 of 90
# Looking for cell edges in frame position 41 of 90
# Looking for cell edges in frame position 42 of 90
# Looking for cell edges in frame position 43 of 90
# Looking for cell edges in frame position 44 of 90
# Looking for cell edges in frame position 45 of 90
# Looking for cell edges in frame position 46 of 90
# Looking for cell edges in frame position 47 of 90
# Looking for cell edges in frame position 48 of 90
# Looking for cell edges in frame position 49 of 90
# Looking for cell edges in frame position 50 of 90
# Looking for cell edges in frame position 51 of 90
# Looking for cell edges in frame position 52 of 90
# Looking for cell edges in frame position 53 of 90
# Looking for cell edges in frame position 54 of 90
# Looking for cell edges in frame position 55 of 90
# Looking for cell edges in frame position 56 of 90
# Looking for cell edges in frame position 57 of 90
# Looking for cell edges in frame position 58 of 90
# Looking for cell edges in frame position 59 of 90
# Looking for cell edges in frame position 60 of 90
# Looking for cell edges in frame position 61 of 90
# Looking for cell edges in frame position 62 of 90
# Looking for cell edges in frame position 63 of 90
# Looking for cell edges in frame position 64 of 90
# Looking for cell edges in frame position 65 of 90
# Looking for cell edges in frame position 66 of 90
# Looking for cell edges in frame position 67 of 90
# Looking for cell edges in frame position 68 of 90
# Looking for cell edges in frame position 69 of 90
# Looking for cell edges in frame position 70 of 90
# Looking for cell edges in frame position 71 of 90
# Looking for cell edges in frame position 72 of 90
# Looking for cell edges in frame position 73 of 90
# Looking for cell edges in frame position 74 of 90
# Looking for cell edges in frame position 75 of 90
# Looking for cell edges in frame position 76 of 90
# Looking for cell edges in frame position 77 of 90
# Looking for cell edges in frame position 78 of 90
# Looking for cell edges in frame position 79 of 90
# Looking for cell edges in frame position 80 of 90
# Looking for cell edges in frame position 81 of 90
# Looking for cell edges in frame position 82 of 90
# Looking for cell edges in frame position 83 of 90
# Looking for cell edges in frame position 84 of 90
# Looking for cell edges in frame position 85 of 90
# Looking for cell edges in frame position 86 of 90
# Looking for cell edges in frame position 87 of 90
# Looking for cell edges in frame position 88 of 90
# Looking for cell edges in frame position 89 of 90
# Looking for cell edges in frame position 90 of 90

# %%
allpeaks = pd.concat(peaks_dfs, ignore_index=True)
allpeaks_table = allpeaks.pivot_table(index=['frame_index', 'theta'], aggfunc='mean').reset_index()
allpeaks_table.head()
# Out:
#    frame_index     theta  first_peak_dist  highest_peak_dist    intensity  \
# 0            0 -3.141593              6.0                9.0  1249.007619
# 1            0 -1.570796              5.0                9.0  1287.516890
# 2            0  0.000000              2.0                9.0  1309.395656
# 3            0  1.570796             11.0                8.0  1288.169905
# 4            1 -3.141593             12.0                9.0  1202.435675
#
#    peak_X  peak_Y  radial_distance  x_center  y_center
# 0    10.5    20.0              9.5      22.5      20.0
# 1    22.5     8.0              9.5      22.5      20.0
# 2    34.5    20.0              9.5      22.5      20.0
# 3    22.5    31.0              9.5      22.5      20.0
# 4    10.5    20.0              9.5      22.5      20.0

# %%
theta = allpeaks.theta[30]
df = allpeaks_table.loc[allpeaks_table.theta == theta]
x = df.frame_index
y = df.highest_peak_dist
plt.plot(x, y)

# %%
fig = plt.figure(figsize=(15, 15))
for i, df in enumerate(peaks_dfs):
    table = df.pivot_table(index='theta', aggfunc='mean').reset_index()
    
    ax = fig.add_subplot(10, 10, i+1)
    ax.imshow(cellcrops[i])
    ax.scatter(table.peak_X, table.peak_Y, color='white')
    ax.set_title(f'frame {i}')
