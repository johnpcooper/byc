# %%
import os

import difflib

import pandas as pd
import numpy as np

from Bio import Seq
from Bio import SeqIO

# %%
path  = r"C:\Users\johnp\Box\Finkelstein-Matouschek\yeast_engineering\yeast_deletion_collection\barcode_index.csv"
bcdex = pd.read_csv(path)

# %%
def read_ab1(path):
    """
    Return Bio.SeqIO record of the .ab1 file at <path>
    """
    handle = open(path, 'rb')
    records = []
    for record in SeqIO.parse(handle, 'abi'):
        records.append(record)
    if len(records) == 1:
        records = records[0]
    else:
        pass
    return records

# %%
datadir = r"C:\Users\johnp\Box\Finkelstein-Matouschek\sanger_sequencing\results\Results_1117368"
filetype = '.ab1'

# Following are written in 5' -> 3' direction
barcode_border_5p = 'GATGTCCACGAGGTCTCT'
barcode_border_3p = 'CGTACGCTGCAGGTCGAC'
uptag_example = 'GATGACAGTACAGTTGACAG'
barcode_len = len(uptag_example)

filenames = [fn for fn in os.listdir(datadir) if filetype == fn[-4:]]
paths = [os.path.join(os.path.abspath(datadir), fn) for fn in filenames]
records = [read_ab1(path) for path in paths]
seqs = [rec.seq for rec in records]

# %%
for idx in range(len(paths)):
    n = 10
    cutoff = 0.3
    seq = seqs[idx]
    print(filenames[idx])
    seq_revcomp = seq.reverse_complement()
    bc_start = seq_revcomp.find(barcode_border_3p) - barcode_len
    bc_end = bc_start + barcode_len
    barcode_seq = seq_revcomp[bc_start: bc_end]
    print(f'Found barcode\n{barcode_seq}')

    barcodes = list(bcdex.UPTAG)
    args = [
        barcode_seq,
        barcodes
    ]
    kwargs = {
        'n': n,
        'cutoff': cutoff
    }
    matches = difflib.get_close_matches(*args, **kwargs)
    wanted_cols = [
        'Gene Symbol',
        'Gene Description',
        'SGD ID'
    ]
    wanted_cols = [
        'Gene Symbol',
        'SGD ID'
    ]
    print(f'Showing top {n} closest matches in deletion collection UPTAG index:')
    print(bcdex.set_index('UPTAG').loc[matches, wanted_cols], '\n')
# Out:
# 12C_001_JPC202-5_MXR3_A03_1117368.ab1
# Found barcode
# ATCATTCCAGCAGATGAAAG
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# ATCATTCCAGCAGTTGGGAG        HRD1  S000005373
# ATCATTAGCAGAGCAGTGAG        SKI7  S000005602
# TCTTCACAGCAAGCAAGGGA     YJL185C  S000003721
# TCACCTACAGATGGGCGAAG        KAR3  S000006345
# TATTTCCAGCCAGGGTGCAG         NaN  S000005946
# TATCGGACCAGCAGGCTAAG        AQY1  S000006396
# TACTATTCAGGAGAGTGACG        TNA1  S000003492
# TACATACCACGACCTTGAAG        MRP2  S000006370
# GCACTCTACAGATGATACAG     YAR023C  S000000074
# CTTCTATTCAGAGATGGAGG        EFM2  S000000475
#
# 12C_002_JPC209-1_MXR3_B03_1117368.ab1
# Found barcode
# GCGCTTCTGCAAGAAGAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# GCGTCTGACATAAGAGCAAC        MPH1  S000001441
# TGCTCCCGGCAAGAGAAACA      PET309  S000004057
# GCGCTGGCACAAGAATACCA       SPS18  S000005148
# GCGCCGACCACAGAATGATA        SOK2  S000004618
# GCGCCATGCAAATGAGCCAA        DRS2  S000000024
# GCATCCTGCACAATGAAGCA        SSO2  S000004795
# CTTTCGGAGCAAGAAGACGA        BIK1  S000000534
# CCTTGCACAGAAGAGATGGA        ICS3  S000003613
# CCTGAATCGCAAGGAAGCTA        BUL1  S000004888
#
# 12C_003_JPC203-1_MXR3_C03_1117368.ab1
# Found barcode
# TTTTTGAGGGGGGGTGGTTT
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# TTCTGAGGCCGAGGTCCTTT        RTG2  S000003221
# TTTCTAGCCCGAGTGGGTCT       EMP24  S000003168
# TTTAGCCGCCGATGGTTCGT         NaN  S000003182
# TTTAGCCGCCGATGGTTCGT         NaN  S000003182
# TTTAGCCGCCGATGGTTCGT         NaN  S000003182
# TTTAGCCGCCGATGGTTCGT         NaN  S000003182
# TTCTGACCCGCGAGTGCTTT         NaN  S000004159
# TTCTATCTCCGACGGTGGGT       MDM34  S000003187
# TTACTTGGGCGATCCGCGTT        RAI1  S000003215
# TCTTCCTGAGGCCGGATGTT        SHH4  S000004154
# TCTACCTCGTGACGGGTGTT        HFM1  S000003220
# TCCTTGACGGCGATGCGATT        DMA2  S000005060
#
# 12C_004_JPC210-1_MXR3_D03_1117368.ab1
# Found barcode
# TTTTCTCTGCAAGAAGAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# TTCCTGGCAAGCAATAGAGA        YEA6  S000000732
# TGCTCCCGGCAAGAGAAACA      PET309  S000004057
# TCCTGCGTAAGAAGAAGTGA         NaN  S000004112
# CTTTCGGAGCAAGAAGACGA        BIK1  S000000534
# TTCCCAGACATGAAAGCGCA        POS5  S000006109
# TTATTCCATCGCAGGAGCGG        KAR5  S000004669
# TTATCACTGGCGAGAGAGCT        GAC1  S000005704
# TGTCCGGCAAGAAACTCCAA         NaN  S000002638
# TCTCTAAGAAGACATCGGGA        NSR1  S000003391
#
# 12C_005_JPC204-1_MXR3_E03_1117368.ab1
# Found barcode
# GCGCCTCTGCAAGAAGAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# GCCCTCGCATAGAAGACATA        RPI1  S000001381
# GCGTCTGACATAAGAGCAAC        MPH1  S000001441
# TGCTCCCGGCAAGAGAAACA      PET309  S000004057
# GTTCGCCACCAAGGAAATCA        SOK1  S000002413
# GGTCCCTCACAAGTAAATCA        TRP1  S000002414
# GGCCTCCGAAGAAAGCTCAA     YDL199C  S000002358
# GGCCACATAGCAGGAACTAC        RCN1  S000001642
# GCGCTGGCACAAGAATACCA       SPS18  S000005148
# GCGCCGACCACAGAATGATA        SOK2  S000004618
#
# 12C_006_JPC211-1_MXR3_F03_1117368.ab1
# Found barcode
# CTATCCTCCCAAGAAGAAAA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# TGCTCCCGGCAAGAGAAACA      PET309  S000004057
# GTTCGCCACCAAGGAAATCA        SOK1  S000002413
# GCTGTCTCCAAAGCACGAAA       AIM34  S000004605
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# GCCCTCGCATAGAAGACATA        RPI1  S000001381
# GCATCCTGCACAATGAAGCA        SSO2  S000004795
# GCACCTCACCAATGATAGGA        TGL3  S000004930
# TTCCTGGCAAGCAATAGAGA        YEA6  S000000732
# TTCCCAGACATGAAAGCGCA        POS5  S000006109
# TGTCCGGCCAAAGAGCCAAA        CRF1  S000002631
#
# 12C_007_JPC205-3_MXR3_G03_1117368.ab1
# Found barcode
# ACAGTGCAGTCATAAGAGTG
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# ACAGTGCAGTCATACGAGTG        SSM4  S000001292
# TACAGGGTCATAAGCGTGTC        ARL3  S000005972
# GATCATGTGCTCTAAGACGG        RRD2  S000006073
# CTAAGTGCGTCTAAGGTACG        IMA1  S000003519
# CATTAGTCATAAGGAGGTGC        ITT1  S000004533
# TGACATGCAGCAGAGCCTAG        PRM4  S000006077
# TCCACGGCTATCATACGGTG        CYB5  S000005055
# TATCCAGTGCCATAGAGGCG        GTO3  S000004863
# TACGTGTACGCAGTCTAGTG     YHR177W  S000001220
# TACATGGCTACAGAGTCCAG        THI6  S000006135
#
# 12C_008_JPC212-3_MXR3_H03_1117368.ab1
# Found barcode
# ACACCTCAGCAAGAAGAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# GCCCTCGCATAGAAGACATA        RPI1  S000001381
# TCTCACATCAGCGAAGATAC        DBR1  S000001632
# TACACGCTCACAGGTACTAG        HST2  S000005936
# GGTCCCTCACAAGTAAATCA        TRP1  S000002414
# GCACTCAGAGAAGTATCCAC        FMS1  S000004622
# GCACGTCAGCAACGCAGATA      RPL34A  S000002135
# GCACCTCACCAATGATAGGA        TGL3  S000004930
# CTTTCGGAGCAAGAAGACGA        BIK1  S000000534
# CTCCATCAGAGAGAGAGCAG         NaN  S000005229
#
# 12C_009_JPC206-1_MXR3_A04_1117368.ab1
# Found barcode
# ATCATTCCAGCAGTTGGGAG
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# ATCATTCCAGCAGTTGGGAG        HRD1  S000005373
# TCATTCCTAACAGTGGCGGC        MID2  S000004324
# ATTCCTACGCCAGTTGTGGG        SIZ1  S000002817
# ATCCATGCTCCAGGTTGGTG        TOF1  S000005217
# ATCATTAGCAGAGCAGTGAG        SKI7  S000005602
# ATCATCAGCCCAGTCGTGAG       BUD21  S000005604
# ATATACGCACGCATTGGGAG        HTZ1  S000005372
# ACTCATCAGGTATGGGAACG        SEA4  S000000200
# AATTCGCACGCAGGTTGACG        FLR1  S000000212
# TTTCTAACAGGCGTTGGAAG        PIN3  S000006358
#
# 12C_010_JPC213-1_MXR3_B04_1117368.ab1
# Found barcode
# ATCATTCCAGCAGTTGGGAG
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# ATCATTCCAGCAGTTGGGAG        HRD1  S000005373
# TCATTCCTAACAGTGGCGGC        MID2  S000004324
# ATTCCTACGCCAGTTGTGGG        SIZ1  S000002817
# ATCCATGCTCCAGGTTGGTG        TOF1  S000005217
# ATCATTAGCAGAGCAGTGAG        SKI7  S000005602
# ATCATCAGCCCAGTCGTGAG       BUD21  S000005604
# ATATACGCACGCATTGGGAG        HTZ1  S000005372
# ACTCATCAGGTATGGGAACG        SEA4  S000000200
# AATTCGCACGCAGGTTGACG        FLR1  S000000212
# TTTCTAACAGGCGTTGGAAG        PIN3  S000006358
#
# 12C_011_JPC207-2_MXR3_C04_1117368.ab1
# Found barcode
# GGGCCTACATCTTTCTCAAG
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# GGGCCTACATCTTTCTCAAG        SAN1  S000002550
# GGAGCGTACATCACTCACAG       AIM36  S000004766
# TGAGCTACACTGTCCGCAAG     YER077C  S000000879
# GGGCAGTCATTCTACTCAAT     YJR146W  S000003907
# GGGCACGTAACAATTCCACA        SHS1  S000002384
# GGCACTACCTAACCTTTAAG        MDR1  S000003332
# GGCACACATTATTCGCAAAC        STB6  S000001555
# GGACTGACACTCTCACATAG        WSS1  S000001176
# GCGGTCGATACATTTCTAAG        SWI5  S000002553
# GCGGCCATCACATATTATCA        MIP1  S000005857
#
# 12C_012_JPC214-2_MXR3_D04_1117368.ab1
# Found barcode
# AGGCATACTACACAGATTCC
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# AGGCATACTACACAGATTCC        SSA1  S000000004
# GGTCTACCTACATAGCATTC     YPR063C  S000006267
# GGGACACTGACACAATTCCA        PLB1  S000004610
# GGCATTACATCAAGATCCAC        STB4  S000004621
# GGCATGACAACAGATCCGCA     YPL245W  S000006166
# GGAGTACCTCACAGTTCTTC        FIN1  S000002537
# GATTCTAACACAGGATCTCC        DGA1  S000005771
# GATACGAGCACAGCAGTTCC         NaN  S000004222
# GAGTGCATTACAGATTACCG        MOG1  S000003835
# GAGTGATCCATACACATTCC        ERP2  S000000005
#
# 12C_013_JPC208-1_MXR3_E04_1117368.ab1
# Found barcode
# ATGCCTACCCAAGAAGAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# TGCTCCCGGCAAGAGAAACA      PET309  S000004057
# GCGCCTCTGCAAGAAGAACA        SSA2  S000003947
# TTGCCATACACAGGAACGAC        CWP1  S000001579
# TGGGCCACTCCAAATAAGCA        CSF1  S000004077
# TGGGCCACAGAAGCAACTCA        RDR1  S000005907
# TGCTGACACCAAGGACCAGA        POR2  S000001376
# TGACGCACCCAACGGAATGA        PBP1  S000003410
# TATGGCACCACACGAAGGAC        AAT1  S000001589
# GTTCGCCACCAAGGAAATCA        SOK1  S000002413
# GTGCGCCTCCAAATCAGAAA        CYB2  S000004518
#
# 12C_014_JPC215-3_MXR3_F04_1117368.ab1
# Found barcode
# TGGCCTATTAAACAAAAACA
# Showing top 10 closest matches in deletion collection UPTAG index:
#                      Gene Symbol      SGD ID
# UPTAG
# TGGGCCACTCCAAATAAGCA        CSF1  S000004077
# TGCGCCATGAGCACAAATAC     YKL133C  S000001616
# TCGGCGCGGTAAACACAACA     YDR239C  S000002647
# TCGCGCTATAAACGAATCCA        ARP6  S000004075
# GTGGGCCTAACACAAGCACA         NaN  S000005852
# GTCGCCTTCATAACAAAGCA        DLT1  S000004733
# GCCTCACTTAAAGCATACGA        HXT2  S000004613
# CGCCGTTATTACAAAGCAAC        CIK1  S000004811
# TTGCCATACACAGGAACGAC        CWP1  S000001579
# TGTCCATGACCACAAATAGC       ADE16  S000004018
